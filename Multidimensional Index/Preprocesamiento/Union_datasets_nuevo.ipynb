# %% [markdown]
# # Dataset Desempleo

# %%
import pandas as pd
from sklearn.preprocessing import OrdinalEncoder
import numpy as np

# %%
dataset_dir = 'Desempleo/desempleo.csv' #Se carga el dataset
df_des = pd.read_csv(dataset_dir, sep=(',')) #Se lee el archivo csv el cual está separado por comas
df_des.isnull().sum() #Se imprime el dataset
# Out:
# CodDepartamento        0
# CodCiudad              0
# Departamento           0
# Ciudad                 0
# Ano                    0
# Trimestre              0
# PorcentajeDesempleo    0
# dtype: int64

# %%
df_des
# Out:
#      CodDepartamento  CodCiudad                Departamento        Ciudad  \
# 0                 44          1                     Guajira      Riohacha
# 1                 54          1          Norte de Santander        Cucuta
# 2                 27          1                       Choco        Quibdo
# 3                 73          1                      Tolima        Ibague
# 4                 41          1                       Huila         Neiva
# ..               ...        ...                         ...           ...
# 283               52          1                      Narino         Pasto
# 284               68          1                   Santander   Bucaramanga
# 285                8          1                   Atlantico  Barranquilla
# 286               13          1                     Bolivar     Cartagena
# 287               88          1  Archipielago de San Andres    San Andres
#
#       Ano  Trimestre  PorcentajeDesempleo
# ...

# %%
df_des['Ciudad'].unique().tolist()
# Out:
# ['Riohacha',
#  'Cucuta',
#  'Quibdo',
#  'Ibague',
#  'Neiva',
#  'Valledupar',
#  'Bogota D.C',
#  'Tunja',
#  'Villavicencio',
#  'Popayan',
#  'Manizales',
#  'Cali',
#  'Armenia',
#  'Medellin',
#  'Monteria',
#  'Florencia',
#  'Santa Marta',
#  'Pereira',
#  'Sincelejo',
#  'Pasto',
#  'Bucaramanga',
#  'Barranquilla',
#  'Cartagena',
#  'San Andres']

# %%
df_des["Ciudad"][df_des["Ciudad"] == "Bogota D.C"] = "Bogota"
df_des["Ciudad"][df_des["Ciudad"] == "Santa Marta"] = "Santamarta"
df_des["Ciudad"][df_des["Ciudad"] == "San Andres"] = "Sanandres"
# Out:
# <ipython-input-5-5d4340dc0b8c>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_des["Ciudad"][df_des["Ciudad"] == "Bogota D.C"] = "Bogota"
# <ipython-input-5-5d4340dc0b8c>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_des["Ciudad"][df_des["Ciudad"] == "Santa Marta"] = "Santamarta"
# <ipython-input-5-5d4340dc0b8c>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# ...

# %%
df_des['Ciudad'].unique().tolist()
# Out:
# ['Riohacha',
#  'Cucuta',
#  'Quibdo',
#  'Ibague',
#  'Neiva',
#  'Valledupar',
#  'Bogota',
#  'Tunja',
#  'Villavicencio',
#  'Popayan',
#  'Manizales',
#  'Cali',
#  'Armenia',
#  'Medellin',
#  'Monteria',
#  'Florencia',
#  'Santamarta',
#  'Pereira',
#  'Sincelejo',
#  'Pasto',
#  'Bucaramanga',
#  'Barranquilla',
#  'Cartagena',
#  'Sanandres']

# %%
df_dese = df_des.loc[df_des.Ciudad == 'Santamarta', ('PorcentajeDesempleo','Trimestre')] 
df_dese
# Out:
#      PorcentajeDesempleo  Trimestre
# 16                  15.6          1
# 40                  16.1          2
# 64                  14.2          3
# 88                  13.4          4
# 112                 13.4          1
# 136                 21.8          2
# 160                 20.7          3
# 184                 16.4          4
# 208                 11.3          1
# 232                 11.4          2
# 256                 11.7          3
# 280                 12.9          4

# %% [markdown]
# # Dataset Temperatura

# %%
dataset_dir = 'TEMP_PRO/Temp_Ciudades.csv' #Se carga el dataset
df_temp = pd.read_csv(dataset_dir, sep=(',')) #Se lee el archivo csv el cual está separado por comas
df_temp.isnull().sum() #Se imprime el dataset
# Out:
# Temperatura    0
# Trimestre      0
# Ano            0
# Ciudad         0
# dtype: int64

# %%
df_temp #Se imprime el dataset
# Out:
#      Temperatura  Trimestre   Ano         Ciudad
# 0      25.477321          1  2019        Armenia
# 1      25.305828          2  2019        Armenia
# 2      27.580615          3  2019        Armenia
# 3      25.338460          4  2019        Armenia
# 4      26.535897          1  2020        Armenia
# ..           ...        ...   ...            ...
# 283    25.909224          4  2020  Villavicencio
# 284    28.580454          1  2021  Villavicencio
# 285    22.871395          2  2021  Villavicencio
# 286    24.068472          3  2021  Villavicencio
# 287    27.394224          4  2021  Villavicencio
#
# [288 rows x 4 columns]

# %%
df_temp['Ciudad'].unique().tolist()
# Out:
# ['Armenia',
#  'Barranquilla',
#  'Bogota',
#  'Bucaramanga',
#  'Cali',
#  'Cartagena',
#  'Cucuta',
#  'Florencia',
#  'Ibague',
#  'Manizales',
#  'Medellin',
#  'Monteria',
#  'Neiva',
#  'Pasto',
#  'Pereira',
#  'Popayan',
#  'Quibdo',
#  'Riohacha',
#  'Sanandres',
#  'Santamarta',
#  'Sincelejo',
#  'Tunja',
#  'Valledupar',
#  'Villavicencio']

# %%
df_des_temp = df_des.merge(df_temp, on=["Ciudad","Ano","Trimestre"], how="outer").fillna(0)
df_des_temp
# Out:
#      CodDepartamento  CodCiudad                Departamento        Ciudad  \
# 0                 44          1                     Guajira      Riohacha
# 1                 54          1          Norte de Santander        Cucuta
# 2                 27          1                       Choco        Quibdo
# 3                 73          1                      Tolima        Ibague
# 4                 41          1                       Huila         Neiva
# ..               ...        ...                         ...           ...
# 283               52          1                      Narino         Pasto
# 284               68          1                   Santander   Bucaramanga
# 285                8          1                   Atlantico  Barranquilla
# 286               13          1                     Bolivar     Cartagena
# 287               88          1  Archipielago de San Andres     Sanandres
#
#       Ano  Trimestre  PorcentajeDesempleo  Temperatura
# ...

# %%
df_des_tempe = df_des_temp.loc[df_des_temp.Ciudad == 'Riohacha', ('PorcentajeDesempleo','Trimestre','Temperatura')] 
df_des_tempe
# Out:
#      PorcentajeDesempleo  Trimestre  Temperatura
# 0                   23.2          1    28.065724
# 24                  18.6          2    27.593695
# 48                  19.1          3    27.749413
# 72                  15.6          4    26.675429
# 96                  17.6          1    30.128272
# 120                 31.5          2    29.332812
# 144                 21.4          3    27.028815
# 168                 19.3          4    25.768921
# 192                 17.1          1    29.412560
# 216                 14.4          2    27.944610
# 240                 14.9          3    29.253872
# 264                 14.6          4    25.806619

# %% [markdown]
# # Dataset Precipitacion

# %%
dataset_dir = 'PRE_PRO/Prec_Ciudades.csv' #Se carga el dataset
df_prec = pd.read_csv(dataset_dir, sep=(',')) #Se lee el archivo csv el cual está separado por comas
df_prec.isnull().sum() #Se imprime el dataset
# Out:
# Precipitacion    1
# Trimestre        0
# Ano              0
# Ciudad           0
# dtype: int64

# %%
df_prec #Se imprime el dataset
# Out:
#      Precipitacion  Trimestre   Ano         Ciudad
# 0        16.237449          1  2019        Armenia
# 1        10.558758          2  2019        Armenia
# 2         7.700481          3  2019        Armenia
# 3        13.061067          4  2019        Armenia
# 4        14.272157          1  2020        Armenia
# ..             ...        ...   ...            ...
# 271      10.364422          4  2020  Villavicencio
# 272       6.299634          1  2021  Villavicencio
# 273      21.517411          2  2021  Villavicencio
# 274      20.065377          3  2021  Villavicencio
# 275       7.209599          4  2021  Villavicencio
#
# [276 rows x 4 columns]

# %%
df_prec['Ciudad'].unique().tolist()
# Out:
# ['Armenia',
#  'Barranquilla',
#  'Bogota',
#  'Bucaramanga',
#  'Cali',
#  'Cartagena',
#  'Cucuta',
#  'Florencia',
#  'Ibague',
#  'Manizales',
#  'Medellin',
#  'Monteria',
#  'Neiva',
#  'Pasto',
#  'Pereira',
#  'Popayan',
#  'Quibdo',
#  'Riohacha',
#  'Santamarta',
#  'Sincelejo',
#  'Tunja',
#  'Valledupar',
#  'Villavicencio']

# %%
df_des_temp_prec = df_des_temp.merge(df_prec, on=["Ciudad","Ano","Trimestre"], how="outer").fillna(0)
df_des_temp_prec
# Out:
#      CodDepartamento  CodCiudad                Departamento        Ciudad  \
# 0                 44          1                     Guajira      Riohacha
# 1                 54          1          Norte de Santander        Cucuta
# 2                 27          1                       Choco        Quibdo
# 3                 73          1                      Tolima        Ibague
# 4                 41          1                       Huila         Neiva
# ..               ...        ...                         ...           ...
# 283               52          1                      Narino         Pasto
# 284               68          1                   Santander   Bucaramanga
# 285                8          1                   Atlantico  Barranquilla
# 286               13          1                     Bolivar     Cartagena
# 287               88          1  Archipielago de San Andres     Sanandres
#
#       Ano  Trimestre  PorcentajeDesempleo  Temperatura  Precipitacion
# ...

# %%
df_des_temp_preci = df_des_temp_prec.loc[df_des_temp_prec.Ciudad == 'Santamarta', ('PorcentajeDesempleo','Trimestre','Temperatura','Precipitacion')] 
df_des_temp_preci
# Out:
#      PorcentajeDesempleo  Trimestre  Temperatura  Precipitacion
# 16                  15.6          1    23.433819       2.484956
# 40                  16.1          2    22.109009       4.633217
# 64                  14.2          3    21.636041       4.975951
# 88                  13.4          4    21.529404       5.520474
# 112                 13.4          1    25.002125       2.118306
# 136                 21.8          2    23.068986       3.184300
# 160                 20.7          3    20.676671       7.539848
# 184                 16.4          4    20.639401      10.336444
# 208                 11.3          1    24.538559       1.859167
# 232                 11.4          2    21.566788       2.561149
# 256                 11.7          3    22.288756       4.827149
# 280                 12.9          4    20.296967       5.486858

# %% [markdown]
# # Dataset PIB

# %%
dataset_dir = 'PIB/PIB2.csv' #Se carga el dataset
df_pib = pd.read_csv(dataset_dir, sep=(',')) #Se lee el archivo csv el cual está separado por comas
df_pib.isnull().sum() #Se imprime el dataset
# Out:
# CodDepartamento    0
# CodCiudad          0
# Departamento       0
# Ciudad             0
# Ano                0
# Trimestre          0
# PIB                0
# dtype: int64

# %%
df_pib #Se imprime el dataset
# Out:
#      CodDepartamento  CodCiudad                Departamento        Ciudad  \
# 0                 44          1                     Guajira      Riohacha
# 1                 54          1          Norte de Santander        Cucuta
# 2                 27          1                       Choco        Quibdo
# 3                 73          1                      Tolima        Ibague
# 4                 41          1                       Huila         Neiva
# ..               ...        ...                         ...           ...
# 187               52          1                      Narino         Pasto
# 188               68          1                   Santander   Bucaramanga
# 189                8          1                   Atlantico  Barranquilla
# 190               13          1                     Bolivar     Cartagena
# 191               88          1  Archipielago de San Andres    San Andres
#
#       Ano  Trimestre    PIB
# 0    2021          1   1851
# ...

# %%
df_pib['Ciudad'].unique().tolist()
# Out:
# ['Riohacha',
#  'Cucuta',
#  'Quibdo',
#  'Ibague',
#  'Neiva',
#  'Valledupar',
#  'Bogota D.C',
#  'Tunja',
#  'Villavicencio',
#  'Popayan',
#  'Manizales',
#  'Cali',
#  'Armenia',
#  'Medellin',
#  'Monteria',
#  'Florencia',
#  'Santa Marta',
#  'Pereira',
#  'Sincelejo',
#  'Pasto',
#  'Bucaramanga',
#  'Barranquilla',
#  'Cartagena',
#  'San Andres']

# %%
df_pib['Ano'].unique().tolist()
# Out:
# [2021, 2020]

# %%
df_pib_b = df_pib[df_pib['Ciudad'] == 'Bogota D.C']
df_pib["Ciudad"][df_pib["Ciudad"] == "Bogota D.C"] = "Bogota"
df_pib["Ciudad"][df_pib["Ciudad"] == "Santa Marta"] = "Santamarta"
df_pib["Ciudad"][df_pib["Ciudad"] == "San Andres"] = "Sanandres"
#df_pib["Departamento"][df_pib["Departamento"] == "Bogota D.C"] = "Bogota"
df_pib
# Out:
# <ipython-input-22-e7a501600774>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_pib["Ciudad"][df_pib["Ciudad"] == "Bogota D.C"] = "Bogota"
# <ipython-input-22-e7a501600774>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_pib["Ciudad"][df_pib["Ciudad"] == "Santa Marta"] = "Santamarta"
# <ipython-input-22-e7a501600774>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# ...

# %%
df_des_temp_prec_pib = df_des_temp_prec.merge(df_pib, on=["Ciudad","Ano","Trimestre","CodDepartamento","CodCiudad","Departamento"], how="outer").fillna(0)
df_des_temp_prec_pib
# Out:
#      CodDepartamento  CodCiudad                Departamento        Ciudad  \
# 0                 44          1                     Guajira      Riohacha
# 1                 54          1          Norte de Santander        Cucuta
# 2                 27          1                       Choco        Quibdo
# 3                 73          1                      Tolima        Ibague
# 4                 41          1                       Huila         Neiva
# ..               ...        ...                         ...           ...
# 283               52          1                      Narino         Pasto
# 284               68          1                   Santander   Bucaramanga
# 285                8          1                   Atlantico  Barranquilla
# 286               13          1                     Bolivar     Cartagena
# 287               88          1  Archipielago de San Andres     Sanandres
#
#       Ano  Trimestre  PorcentajeDesempleo  Temperatura  Precipitacion     PIB
# ...

# %%
df_des_temp_prec_pib['Ano'].unique().tolist()
# Out:
# [2021, 2020, 2019]

# %%
df_des_temp_prec_pibi = df_des_temp_prec_pib.loc[df_des_temp_prec_pib.Ciudad == 'Bogota', ('PorcentajeDesempleo','Trimestre','Ano','Temperatura','Precipitacion','PIB')] 
df_des_temp_prec_pibi
# Out:
#      PorcentajeDesempleo  Trimestre   Ano  Temperatura  Precipitacion  \
# 6                   20.1          1  2021    19.989400       3.990287
# 30                  18.1          2  2021    16.620689       6.277958
# 54                  14.4          3  2021    16.012740       5.815894
# 78                  11.3          4  2021    19.065336       5.417185
# 102                 11.8          1  2020    22.723783       4.945249
# 126                 23.6          2  2020    17.397859       5.342135
# 150                 22.0          3  2020    17.546153       6.109085
# 174                 16.3          4  2020    19.471980       4.959516
# 198                 13.4          1  2019    19.857304       4.382859
# 222                 10.3          2  2019    17.362795       5.238121
# 246                 10.0          3  2019    16.392629       3.219855
# 270                  9.9          4  2019    18.032462       5.560449
#
#           PIB
# 6    237244.0
# 30   237244.0
# ...

# %%
df_des_temp_prec_pib = df_des_temp_prec_pib.replace([0], [np.nan])
df_des_temp_prec_pib
# Out:
#      CodDepartamento  CodCiudad                Departamento        Ciudad  \
# 0                 44          1                     Guajira      Riohacha
# 1                 54          1          Norte de Santander        Cucuta
# 2                 27          1                       Choco        Quibdo
# 3                 73          1                      Tolima        Ibague
# 4                 41          1                       Huila         Neiva
# ..               ...        ...                         ...           ...
# 283               52          1                      Narino         Pasto
# 284               68          1                   Santander   Bucaramanga
# 285                8          1                   Atlantico  Barranquilla
# 286               13          1                     Bolivar     Cartagena
# 287               88          1  Archipielago de San Andres     Sanandres
#
#       Ano  Trimestre  PorcentajeDesempleo  Temperatura  Precipitacion     PIB
# ...

# %%
df_des_temp_prec_pib.isnull().sum() #Se imprime el dataset
# Out:
# CodDepartamento         0
# CodCiudad               0
# Departamento            0
# Ciudad                  0
# Ano                     0
# Trimestre               0
# PorcentajeDesempleo     0
# Temperatura             0
# Precipitacion          13
# PIB                    96
# dtype: int64

# %%
#df_des_temp_prec_pibr = df_des_temp_prec_pib.drop(df_des_temp_prec_pib[df_des_temp_prec_pib['PIB'] != 'NaN'].index)
#df_des_temp_prec_pibr = df_des_temp_prec_pib['PIB'] != np.NaN
#df_des_temp_prec_pibr = df_des_temp_prec_pib[df_des_temp_prec_pibr]
#df_des_temp_prec_pibr = df_des_temp_prec_pib
#df_des_temp_prec_pibr = df_des_temp_prec_pibr.dropna()
#df_des_temp_prec_pibr

# %% [markdown]
# # Mobility

# %%
dataset_dir = 'MOB_PRO/Mobi_Ciudades.csv' #Se carga el dataset
df_mobi = pd.read_csv(dataset_dir, sep=(',')) #Se lee el archivo csv el cual está separado por comas
df_mobi.isnull().sum() #Se imprime el dataset
# Out:
# retail_and_recreation    0
# grocery_and_pharmacy     0
# parks                    0
# transit_stations         0
# workplaces               0
# residential              0
# Trimestre                0
# Ano                      0
# Ciudad                   0
# dtype: int64

# %%
df_des_temp_prec_pib_mob = df_des_temp_prec_pib.merge(df_mobi, on=["Ciudad","Ano","Trimestre"], how="outer").fillna(0)
df_des_temp_prec_pib_mob
# Out:
#      CodDepartamento  CodCiudad                Departamento        Ciudad  \
# 0                 44          1                     Guajira      Riohacha
# 1                 54          1          Norte de Santander        Cucuta
# 2                 27          1                       Choco        Quibdo
# 3                 73          1                      Tolima        Ibague
# 4                 41          1                       Huila         Neiva
# ..               ...        ...                         ...           ...
# 283               52          1                      Narino         Pasto
# 284               68          1                   Santander   Bucaramanga
# 285                8          1                   Atlantico  Barranquilla
# 286               13          1                     Bolivar     Cartagena
# 287               88          1  Archipielago de San Andres     Sanandres
#
#       Ano  Trimestre  PorcentajeDesempleo  Temperatura  Precipitacion     PIB  \
# ...

# %%
df_des_temp_prec_pib_mobi = df_des_temp_prec_pib_mob.loc[df_des_temp_prec_pib_mob.Ciudad == 'Quibdo', ('PorcentajeDesempleo','Trimestre','Temperatura','Precipitacion','PIB','parks')] 
df_des_temp_prec_pib_mobi
# Out:
#      PorcentajeDesempleo  Trimestre  Temperatura  Precipitacion    PIB  \
# 2                   21.9          1    19.581721      16.377159  842.0
# 26                  21.9          2    19.564816      17.580874  842.0
# 50                  18.6          3    20.526362      14.488672  842.0
# 74                  19.9          4    18.334506      19.801086  842.0
# 98                  22.5          1    19.108803       7.459441  784.0
# 122                 18.0          2    20.529986      20.158935  784.0
# 146                 21.2          3    20.523398      20.473434  784.0
# 170                 20.0          4    18.812696      19.846019  784.0
# 194                 21.6          1    18.158435       8.379369    0.0
# 218                 20.3          2    19.388668      22.994865    0.0
# 242                 18.4          3    19.524672      21.672899    0.0
# 266                 18.9          4    17.773071      24.114349    0.0
#
#          parks
# 2    18.042243
# ...

# %% [markdown]
# # Vacunacion

# %%
dataset_dir = 'Vacunacion/Vacunacion.csv' #Se carga el dataset
df_vac = pd.read_csv(dataset_dir, sep=(',')) #Se lee el archivo csv el cual está separado por comas
df_vac.isnull().sum() #Se imprime el dataset
# Out:
# CodDepartamento         0
# CodCiudad               0
# Departamento            0
# Ciudad                  0
# Ano                     0
# Trimestre               0
# PorcentajeVacunacion    0
# dtype: int64

# %%
df_vac
# Out:
#      CodDepartamento  CodCiudad                Departamento        Ciudad  \
# 0                 44          1                     Guajira      Riohacha
# 1                 54          1          Norte de Santander        Cucuta
# 2                 27          1                       Choco        Quibdo
# 3                 73          1                      Tolima        Ibague
# 4                 41          1                       Huila         Neiva
# ..               ...        ...                         ...           ...
# 259               52          1                      Narino         Pasto
# 260               68          1                   Santander   Bucaramanga
# 261                8          1                   Atlantico  Barranquilla
# 262               13          1                     Bolivar     Cartagena
# 263               88          1  Archipielago de San Andres    San Andres
#
#       Ano  Trimestre  PorcentajeVacunacion
# ...

# %%
df_vacuna = df_vac.loc[df_vac.Ciudad == 'Popayan', ('Ciudad','Departamento','Ano','Trimestre','PorcentajeVacunacion')] 
df_vacuna
# Out:
#       Ciudad Departamento   Ano  Trimestre  PorcentajeVacunacion
# 9    Popayan        Cauca  2020          1                  0.00
# 33   Popayan        Cauca  2020          2                  0.00
# 57   Popayan        Cauca  2020          3                  0.00
# 81   Popayan        Cauca  2020          4                  0.00
# 105  Popayan        Cauca  2021          1                  0.92
# 129  Popayan        Cauca  2021          2                 18.05
# 153  Popayan        Cauca  2021          3                 39.46
# 177  Popayan        Cauca  2021          4                 59.48
# 201  Popayan        Cauca  2022          1                 67.62
# 225  Popayan        Cauca  2022          2                 69.72
# 249  Popayan        Cauca  2022          3                 70.58

# %%
df_vac["Ciudad"][df_vac["Ciudad"] == "Bogota D.C"] = "Bogota"
df_vac["Ciudad"][df_vac["Ciudad"] == "Santa Marta"] = "Santamarta"
df_vac["Ciudad"][df_vac["Ciudad"] == "San Andres"] = "Sanandres"
#df_pib["Departamento"][df_pib["Departamento"] == "Bogota D.C"] = "Bogota"
df_vac
# Out:
# <ipython-input-35-5012ec589c3b>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_vac["Ciudad"][df_vac["Ciudad"] == "Bogota D.C"] = "Bogota"
# <ipython-input-35-5012ec589c3b>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_vac["Ciudad"][df_vac["Ciudad"] == "Santa Marta"] = "Santamarta"
# <ipython-input-35-5012ec589c3b>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# ...

# %%
df_des_temp_prec_pib_mob_vac = df_des_temp_prec_pib_mob.merge(df_vac, on=["Ciudad","Ano","Trimestre","CodDepartamento","CodCiudad","Departamento"], how="outer").fillna(0)
df_des_temp_prec_pib_mob_vac
# Out:
#      CodDepartamento  CodCiudad                Departamento        Ciudad  \
# 0                 44          1                     Guajira      Riohacha
# 1                 54          1          Norte de Santander        Cucuta
# 2                 27          1                       Choco        Quibdo
# 3                 73          1                      Tolima        Ibague
# 4                 41          1                       Huila         Neiva
# ..               ...        ...                         ...           ...
# 355               52          1                      Narino         Pasto
# 356               68          1                   Santander   Bucaramanga
# 357                8          1                   Atlantico  Barranquilla
# 358               13          1                     Bolivar     Cartagena
# 359               88          1  Archipielago de San Andres     Sanandres
#
#       Ano  Trimestre  PorcentajeDesempleo  Temperatura  Precipitacion     PIB  \
# ...

# %%
df_des_temp_prec_pib_mob_vacu = df_des_temp_prec_pib_mob_vac.loc[df_des_temp_prec_pib_mob_vac.Ciudad == 'Medellin', ('PorcentajeDesempleo','Trimestre','Temperatura','Precipitacion','PIB','Ano')] 
df_des_temp_prec_pib_mob_vacu
# Out:
#      PorcentajeDesempleo  Trimestre  Temperatura  Precipitacion      PIB   Ano
# 13                  17.9          1    22.285123       6.276447  52347.0  2021
# 37                  16.1          2    21.641045       6.918125  52347.0  2021
# 61                  15.1          3    22.108254       5.659602  52347.0  2021
# 85                  13.0          4    21.652813       7.864118  52347.0  2021
# 109                 12.9          1    24.149651       7.957837  46018.0  2020
# 133                 25.2          2    22.286968       5.173339  46018.0  2020
# 157                 20.0          3    22.739094       7.672982  46018.0  2020
# 181                 15.2          4    23.157370       8.176094  46018.0  2020
# 205                 13.5          1    22.628148       7.196210      0.0  2019
# 229                 12.6          2    22.486640       7.895154      0.0  2019
# 253                 12.0          3    23.582326       3.777443      0.0  2019
# ...

# %% [markdown]
# # Indice vulnerabilidad DANE

# %%
dataset_dir = 'Indice_DANE\\vulnerabilidad_median_filtered_municipalities_no_0.CSV' #Se carga el dataset
df_dataset_y = pd.read_csv(dataset_dir, sep=(',')) #Se lee el archivo csv el cual está separado por comas
df_dataset_y
# Out:
#     COD_MPIO  CATEGORIA        ipm  Vulnerabilidad_numero
# 0       5001        4.0   8.900000                      2
# 1       8001        4.0  10.800000                      2
# 2      11001        3.0   7.400000                      2
# 3      13001        1.0  12.100000                      1
# 4      15001        4.0   4.240336                      1
# 5      17001        4.0   8.200000                      1
# 6      18001        4.0  18.644068                      1
# 7      19001        2.0  10.000000                      4
# 8      20001        1.0  17.465098                      1
# 9      23001        4.0  12.096774                      1
# 10     27001        1.0  33.215649                      1
# 11     41001        4.0   7.692308                      1
# 12     44001        4.0  24.210526                      2
# 13     47001        3.0  12.272426                      1
# 14     50001        3.0   9.700000                      2
# ...

# %%
df_dataset_y = df_dataset_y.astype(str)

# %%
df_dataset_y["CodCiudad"] = df_dataset_y['COD_MPIO'].apply(lambda x: x[-3:])
df_dataset_y["CodDepartamento"] = df_dataset_y['COD_MPIO'].apply(lambda x: x[:-3])
df_dataset_y
# Out:
#    COD_MPIO CATEGORIA                 ipm Vulnerabilidad_numero CodCiudad  \
# 0      5001       4.0                 8.9                     2       001
# 1      8001       4.0                10.8                     2       001
# 2     11001       3.0                 7.4                     2       001
# 3     13001       1.0                12.1                     1       001
# 4     15001       4.0   4.240335631000001                     1       001
# 5     17001       4.0                 8.2                     1       001
# 6     18001       4.0  18.644067800000002                     1       001
# 7     19001       2.0                10.0                     4       001
# 8     20001       1.0         17.46509849                     1       001
# 9     23001       4.0         12.09677419                     1       001
# 10    27001       1.0        33.215649225                     1       001
# 11    41001       4.0   7.692307692000001                     1       001
# ...

# %%
df_dataset_y.CodCiudad = df_dataset_y.CodCiudad.astype(int) 
df_dataset_y.CodDepartamento = df_dataset_y.CodDepartamento.astype(int)  
print(df_dataset_y.dtypes)
df_dataset_y =df_dataset_y.loc[:,["Vulnerabilidad_numero","CodCiudad","CodDepartamento"]]
df_dataset_y
# Out:
# COD_MPIO                 object
# CATEGORIA                object
# ipm                      object
# Vulnerabilidad_numero    object
# CodCiudad                 int32
# CodDepartamento           int32
# dtype: object
#    Vulnerabilidad_numero  CodCiudad  CodDepartamento
# 0                      2          1                5
# 1                      2          1                8
# 2                      2          1               11
# 3                      1          1               13
# 4                      1          1               15
# 5                      1          1               17
# 6                      1          1               18
# 7                      4          1               19
# 8                      1          1               20
# 9                      1          1               23
# 10                     1          1               27
# 11                     1          1               41
# 12                     2          1               44
# ...

# %%
df_fin = df_des_temp_prec_pib_mob_vac.merge(df_dataset_y, on=["CodCiudad","CodDepartamento"], how="outer").fillna(0)
df_fin
# Out:
#      CodDepartamento  CodCiudad                Departamento     Ciudad   Ano  \
# 0                 44          1                     Guajira   Riohacha  2021
# 1                 44          1                     Guajira   Riohacha  2021
# 2                 44          1                     Guajira   Riohacha  2021
# 3                 44          1                     Guajira   Riohacha  2021
# 4                 44          1                     Guajira   Riohacha  2020
# ..               ...        ...                         ...        ...   ...
# 355               88          1  Archipielago de San Andres  Sanandres  2019
# 356               88          1  Archipielago de San Andres  Sanandres  2019
# 357               88          1  Archipielago de San Andres  Sanandres  2022
# 358               88          1  Archipielago de San Andres  Sanandres  2022
# 359               88          1  Archipielago de San Andres  Sanandres  2022
#
# ...

# %%
df_fin = df_fin.sort_values(['CodDepartamento','Ano','Trimestre'])
df_fin
# Out:
#      CodDepartamento  CodCiudad                Departamento     Ciudad   Ano  \
# 203                5          1                   Antioquia   Medellin  2019
# 204                5          1                   Antioquia   Medellin  2019
# 205                5          1                   Antioquia   Medellin  2019
# 206                5          1                   Antioquia   Medellin  2019
# 199                5          1                   Antioquia   Medellin  2020
# ..               ...        ...                         ...        ...   ...
# 347               88          1  Archipielago de San Andres  Sanandres  2021
# 348               88          1  Archipielago de San Andres  Sanandres  2021
# 357               88          1  Archipielago de San Andres  Sanandres  2022
# 358               88          1  Archipielago de San Andres  Sanandres  2022
# 359               88          1  Archipielago de San Andres  Sanandres  2022
#
# ...

# %%
df_fin.reset_index(drop=True)
# Out:
#      CodDepartamento  CodCiudad                Departamento     Ciudad   Ano  \
# 0                  5          1                   Antioquia   Medellin  2019
# 1                  5          1                   Antioquia   Medellin  2019
# 2                  5          1                   Antioquia   Medellin  2019
# 3                  5          1                   Antioquia   Medellin  2019
# 4                  5          1                   Antioquia   Medellin  2020
# ..               ...        ...                         ...        ...   ...
# 355               88          1  Archipielago de San Andres  Sanandres  2021
# 356               88          1  Archipielago de San Andres  Sanandres  2021
# 357               88          1  Archipielago de San Andres  Sanandres  2022
# 358               88          1  Archipielago de San Andres  Sanandres  2022
# 359               88          1  Archipielago de San Andres  Sanandres  2022
#
# ...

# %% [markdown]
# # Incidencia

# %%
dataset_dir = 'Incidencia/Incidencia.csv' #Se carga el dataset
df_inc = pd.read_csv(dataset_dir, sep=(',')) #Se lee el archivo csv el cual está separado por comas
df_inc
# Out:
#      Trimestre   Ano         Ciudad  Incidencia
# 0            1  2019        Armenia    0.000000
# 1            2  2019        Armenia    0.000000
# 2            3  2019        Armenia    0.000000
# 3            4  2019        Armenia    0.000000
# 4            1  2020        Armenia    0.000043
# ..         ...   ...            ...         ...
# 283          4  2020  Villavicencio    0.024121
# 284          1  2021  Villavicencio    0.012760
# 285          2  2021  Villavicencio    0.039040
# 286          3  2021  Villavicencio    0.014033
# 287          4  2021  Villavicencio    0.002469
#
# [288 rows x 4 columns]

# %%
df_total = df_fin.merge(df_inc, on=['Trimestre','Ano','Ciudad'], how="outer")
df_total
# Out:
#      CodDepartamento  CodCiudad                Departamento     Ciudad   Ano  \
# 0                  5          1                   Antioquia   Medellin  2019
# 1                  5          1                   Antioquia   Medellin  2019
# 2                  5          1                   Antioquia   Medellin  2019
# 3                  5          1                   Antioquia   Medellin  2019
# 4                  5          1                   Antioquia   Medellin  2020
# ..               ...        ...                         ...        ...   ...
# 355               88          1  Archipielago de San Andres  Sanandres  2021
# 356               88          1  Archipielago de San Andres  Sanandres  2021
# 357               88          1  Archipielago de San Andres  Sanandres  2022
# 358               88          1  Archipielago de San Andres  Sanandres  2022
# 359               88          1  Archipielago de San Andres  Sanandres  2022
#
# ...

# %%
col = ['Ciudad','Trimestre','Ano','PIB']
ddata = pd.DataFrame(df_fin,columns=col)
ddata.head(30)
# Out:
#            Ciudad  Trimestre   Ano      PIB
# 203      Medellin          1  2019      0.0
# 204      Medellin          2  2019      0.0
# 205      Medellin          3  2019      0.0
# 206      Medellin          4  2019      0.0
# 199      Medellin          1  2020  46018.0
# 200      Medellin          2  2020  46018.0
# 201      Medellin          3  2020  46018.0
# 202      Medellin          4  2020  46018.0
# 195      Medellin          1  2021  52347.0
# 196      Medellin          2  2021  52347.0
# 197      Medellin          3  2021  52347.0
# 198      Medellin          4  2021  52347.0
# 207      Medellin          1  2022      0.0
# 208      Medellin          2  2022      0.0
# 209      Medellin          3  2022      0.0
# 323  Barranquilla          1  2019      0.0
# 324  Barranquilla          2  2019      0.0
# 325  Barranquilla          3  2019      0.0
# 326  Barranquilla          4  2019      0.0
# 319  Barranquilla          1  2020  16933.0
# ...

# %% [markdown]
# import scipy
#
# from scipy.interpolate import interp1d
#
# arr = df_total['PIB']
# df_fin.loc[df_fin['PIB'] == 0, 'PIB'] = np.nan
#
# #df_arm = df_fin['PIB'].replace([0],[np.nan])
# df_arm = df_fin[df_fin['Ciudad'] == 'Armenia']
# df_arm = df_arm['PIB'].unique().tolist()
# df_arm = pd.Series(df_arm)
# #val = df_arm[0] - df_arm[1]
# #extra = dict(method="linear", fill_value="extrapolate")
# #df_arm.interpolate()
# #df_arm.interpolate(method='linear', limit_area=None)
# f_linear = scipy.interpolate.interp1d(x,y)
# #df_arm

# %%
df_total = df_total.drop(df_total[df_total['Ano'] == 2019].index)
df_total = df_total.drop(df_total[df_total['Ano'] == 2022].index)
df_total.reset_index(drop=True, inplace=True)
df_total
# Out:
#      CodDepartamento  CodCiudad                Departamento     Ciudad   Ano  \
# 0                  5          1                   Antioquia   Medellin  2020
# 1                  5          1                   Antioquia   Medellin  2020
# 2                  5          1                   Antioquia   Medellin  2020
# 3                  5          1                   Antioquia   Medellin  2020
# 4                  5          1                   Antioquia   Medellin  2021
# ..               ...        ...                         ...        ...   ...
# 187               88          1  Archipielago de San Andres  Sanandres  2020
# 188               88          1  Archipielago de San Andres  Sanandres  2021
# 189               88          1  Archipielago de San Andres  Sanandres  2021
# 190               88          1  Archipielago de San Andres  Sanandres  2021
# 191               88          1  Archipielago de San Andres  Sanandres  2021
#
# ...

# %%
df_total.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 192 entries, 0 to 191
# Data columns (total 19 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   CodDepartamento        192 non-null    int64
#  1   CodCiudad              192 non-null    int64
#  2   Departamento           192 non-null    object
#  3   Ciudad                 192 non-null    object
#  4   Ano                    192 non-null    int64
#  5   Trimestre              192 non-null    int64
#  6   PorcentajeDesempleo    192 non-null    float64
#  7   Temperatura            192 non-null    float64
#  8   Precipitacion          192 non-null    float64
#  9   PIB                    192 non-null    float64
#  10  retail_and_recreation  192 non-null    float64
#  11  grocery_and_pharmacy   192 non-null    float64
#  12  parks                  192 non-null    float64
#  13  transit_stations       192 non-null    float64
# ...

# %%
df_total['Vulnerabilidad_numero'] = df_total['Vulnerabilidad_numero'].astype('float64')
df_total.tail(30)
# Out:
#      CodDepartamento  CodCiudad                Departamento     Ciudad   Ano  \
# 162               70          1                       Sucre  Sincelejo  2020
# 163               70          1                       Sucre  Sincelejo  2020
# 164               70          1                       Sucre  Sincelejo  2021
# 165               70          1                       Sucre  Sincelejo  2021
# 166               70          1                       Sucre  Sincelejo  2021
# 167               70          1                       Sucre  Sincelejo  2021
# 168               73          1                      Tolima     Ibague  2020
# 169               73          1                      Tolima     Ibague  2020
# 170               73          1                      Tolima     Ibague  2020
# 171               73          1                      Tolima     Ibague  2020
# 172               73          1                      Tolima     Ibague  2021
# ...

# %% [markdown]
# from sklearn import preprocessing
# vuln_esc = df_total['Vulnerabilidad_numero']
# vuln_esc = np.array(vuln_esc).reshape(-1,1)
# scaler = preprocessing.MinMaxScaler()
# normalizedlist=scaler.fit_transform(vuln_esc)
# vuln_esc = normalizedlist*5
# vuln_esc
# df_total['Vulnerabilidad_numero'] = vuln_esc
# df_total

# %%
df = df_total.drop(["CodCiudad","Departamento","Ciudad"], axis =1)
df.head(30)
# Out:
#     CodDepartamento   Ano  Trimestre  PorcentajeDesempleo  Temperatura  \
# 0                 5  2020          1                 12.9    24.149651
# 1                 5  2020          2                 25.2    22.286968
# 2                 5  2020          3                 20.0    22.739094
# 3                 5  2020          4                 15.2    23.157370
# 4                 5  2021          1                 17.9    22.285123
# 5                 5  2021          2                 16.1    21.641045
# 6                 5  2021          3                 15.1    22.108254
# 7                 5  2021          4                 13.0    21.652813
# 8                 8  2020          1                  9.1    34.549735
# 9                 8  2020          2                 15.9    35.437985
# 10                8  2020          3                 12.3    31.819404
# 11                8  2020          4                 12.3    29.727768
# ...

# %%
export_dir = 'Dataset_Final/Dataset_unido.csv'
df.to_csv(export_dir, index=False, header=True)
