# %%
import csv

# %%
with open('Vacunacion.csv', 'w') as csvfile:
    fieldnames= ['CodDepartamento','CodCiudad','Departamento','Ciudad','Ano','Trimestre','PorcentajeVacunacion']
    writer = csv.DictWriter(csvfile, fieldnames=fieldnames)
    
    writer.writeheader()
    
    #AÑO 2020
    
    writer.writerow({'CodDepartamento': '44',
                     'CodCiudad':'001',
                     'Departamento':'Guajira',
                     'Ciudad':'Riohacha',
                     'Ano':'2020',
                     'Trimestre':'1',
                     'PorcentajeVacunacion':'0'})
    writer.writerow({'CodDepartamento': '54',
                     'CodCiudad':'001',
                     'Departamento': 'Norte de Santander',
                     'Ciudad':'Cucuta',
                     'Ano':'2020',
                     'Trimestre':'1',
                     'PorcentajeVacunacion':'0'})
    writer.writerow({'CodDepartamento': '27',
                     'CodCiudad':'001',
                     'Departamento': 'Choco',
                     'Ciudad':'Quibdo',
                     'Ano':'2020',
                     'Trimestre':'1',
                     'PorcentajeVacunacion':'0'})
    writer.writerow({'CodDepartamento': '73',
                     'CodCiudad':'001',
                     'Departamento': 'Tolima',
                     'Ciudad':'Ibague',
                     'Ano':'2020',
                     'Trimestre':'1',
                     'PorcentajeVacunacion':'0'})
    writer.writerow({'CodDepartamento': '41',
                     'CodCiudad':'001',
                     'Departamento': 'Huila',
                     'Ciudad':'Neiva',
                     'Ano':'2020',
                     'Trimestre':'1',
                     'PorcentajeVacunacion':'0'})
    writer.writerow({'CodDepartamento': '20',
                     'CodCiudad':'001',
                     'Departamento': 'Cesar',
                     'Ciudad':'Valledupar',
                     'Ano':'2020',
                     'Trimestre':'1',
                     'PorcentajeVacunacion':'0'})
    writer.writerow({'CodDepartamento': '11',
                     'CodCiudad':'001',
                     'Departamento': 'Bogota D.C',
                     'Ciudad':'Bogota D.C',
                     'Ano':'2020',
                     'Trimestre':'1',
                     'PorcentajeVacunacion':'0'})
    writer.writerow({'CodDepartamento': '15',
                     'CodCiudad':'001',
                     'Departamento': 'Boyaca',
                     'Ciudad':'Tunja',
                     'Ano':'2020',
                     'Trimestre':'1',
                     'PorcentajeVacunacion':'0'})
    writer.writerow({'CodDepartamento': '50',
                     'CodCiudad':'001',
                     'Departamento': 'Meta',
                     'Ciudad':'Villavicencio',
                     'Ano':'2020',
                     'Trimestre':'1',
                     'PorcentajeVacunacion':'0'})
    writer.writerow({'CodDepartamento': '19',
                     'CodCiudad':'001',
                     'Departamento': 'Cauca',
                     'Ciudad':'Popayan',
                     'Ano':'2020',
                     'Trimestre':'1',
                     'PorcentajeVacunacion':'0'})
    writer.writerow({'CodDepartamento': '17',
                     'CodCiudad':'001',
                     'Departamento': 'Caldas',
                     'Ciudad':'Manizales',
                     'Ano':'2020',
                     'Trimestre':'1',
                     'PorcentajeVacunacion':'0'})
    writer.writerow({'CodDepartamento': '76',
                     'CodCiudad':'001',
                     'Departamento': 'Valle del Cauca',
                     'Ciudad':'Cali',
                     'Ano':'2020',
                     'Trimestre':'1',
                     'PorcentajeVacunacion':'0'})
    writer.writerow({'CodDepartamento': '63',
                     'CodCiudad':'001',
                     'Departamento': 'Quindio',
                     'Ciudad':'Armenia',
                     'Ano':'2020',
                     'Trimestre':'1',
                     'PorcentajeVacunacion':'0'})
    writer.writerow({'CodDepartamento': '05',
                     'CodCiudad':'001',
                     'Departamento': 'Antioquia',
                     'Ciudad':'Medellin',
                     'Ano':'2020',
                     'Trimestre':'1',
                     'PorcentajeVacunacion':'0'})
    writer.writerow({'CodDepartamento': '23',
                     'CodCiudad':'001',
                     'Departamento': 'Cordoba',
                     'Ciudad':'Monteria',
                     'Ano':'2020',
                     'Trimestre':'1',
                     'PorcentajeVacunacion':'0'})
    writer.writerow({'CodDepartamento': '18',
                     'CodCiudad':'001',
                     'Departamento': 'Caqueta',
                     'Ciudad':'Florencia',
                     'Ano':'2020',
                     'Trimestre':'1',
                     'PorcentajeVacunacion':'0'})
    writer.writerow({'CodDepartamento': '47',
                     'CodCiudad':'001',
                     'Departamento': 'Magdalena',
                     'Ciudad':'Santa Marta',
                     'Ano':'2020',
                     'Trimestre':'1',
                     'PorcentajeVacunacion':'0'})
    writer.writerow({'CodDepartamento': '66',
                     'CodCiudad':'001',
                     'Departamento': 'Risaralda',
                     'Ciudad':'Pereira',
                     'Ano':'2020',
                     'Trimestre':'1',
                     'PorcentajeVacunacion':'0'})
    writer.writerow({'CodDepartamento': '70',
                     'CodCiudad':'001',
                     'Departamento': 'Sucre',
                     'Ciudad':'Sincelejo',
                     'Ano':'2020',
                     'Trimestre':'1',
                     'PorcentajeVacunacion':'0'})
    writer.writerow({'CodDepartamento': '52',
                     'CodCiudad':'001',
                     'Departamento': 'Narino',
                     'Ciudad':'Pasto',
                     'Ano':'2020',
                     'Trimestre':'1',
                     'PorcentajeVacunacion':'0'})
    writer.writerow({'CodDepartamento': '68',
                     'CodCiudad':'001',
                     'Departamento': 'Santander',
                     'Ciudad':'Bucaramanga',
                     'Ano':'2020',
                     'Trimestre':'1',
                     'PorcentajeVacunacion':'0'})
    writer.writerow({'CodDepartamento': '08',
                     'CodCiudad':'001',
                     'Departamento': 'Atlantico',
                     'Ciudad':'Barranquilla',
                     'Ano':'2020',
                     'Trimestre':'1',
                     'PorcentajeVacunacion':'0'})
    writer.writerow({'CodDepartamento': '13',
                     'CodCiudad':'001',
                     'Departamento': 'Bolivar',
                     'Ciudad':'Cartagena',
                     'Ano':'2020',
                     'Trimestre':'1',
                     'PorcentajeVacunacion':'0'})
    writer.writerow({'CodDepartamento': '88',
                     'CodCiudad':'001',
                     'Departamento': 'Archipielago de San Andres',
                     'Ciudad':'San Andres',
                     'Ano':'2020',
                     'Trimestre':'1',
                     'PorcentajeVacunacion':'0'})
    writer.writerow({'CodDepartamento': '44',
                     'CodCiudad':'001',
                     'Departamento':'Guajira',
                     'Ciudad':'Riohacha',
                     'Ano':'2020',
                     'Trimestre':'2',
                     'PorcentajeVacunacion':'0'})
    writer.writerow({'CodDepartamento': '54',
                     'CodCiudad':'001',
                     'Departamento': 'Norte de Santander',
                     'Ciudad':'Cucuta',
                     'Ano':'2020',
                     'Trimestre':'2',
                     'PorcentajeVacunacion':'0'})
    writer.writerow({'CodDepartamento': '27',
                     'CodCiudad':'001',
                     'Departamento': 'Choco',
                     'Ciudad':'Quibdo',
                     'Ano':'2020',
                     'Trimestre':'2',
                     'PorcentajeVacunacion':'0'})
    writer.writerow({'CodDepartamento': '73',
                     'CodCiudad':'001',
                     'Departamento': 'Tolima',
                     'Ciudad':'Ibague',
                     'Ano':'2020',
                     'Trimestre':'2',
                     'PorcentajeVacunacion':'0'})
    writer.writerow({'CodDepartamento': '41',
                     'CodCiudad':'001',
                     'Departamento': 'Huila',
                     'Ciudad':'Neiva',
                     'Ano':'2020',
                     'Trimestre':'2',
                     'PorcentajeVacunacion':'0'})
    writer.writerow({'CodDepartamento': '20',
                     'CodCiudad':'001',
                     'Departamento': 'Cesar',
                     'Ciudad':'Valledupar',
                     'Ano':'2020',
                     'Trimestre':'2',
                     'PorcentajeVacunacion':'0'})
    writer.writerow({'CodDepartamento': '11',
                     'CodCiudad':'001',
                     'Departamento': 'Bogota D.C',
                     'Ciudad':'Bogota D.C',
                     'Ano':'2020',
                     'Trimestre':'2',
                     'PorcentajeVacunacion':'0'})
    writer.writerow({'CodDepartamento': '15',
                     'CodCiudad':'001',
                     'Departamento': 'Boyaca',
                     'Ciudad':'Tunja',
                     'Ano':'2020',
                     'Trimestre':'2',
                     'PorcentajeVacunacion':'0'})
    writer.writerow({'CodDepartamento': '50',
                     'CodCiudad':'001',
                     'Departamento': 'Meta',
                     'Ciudad':'Villavicencio',
                     'Ano':'2020',
                     'Trimestre':'2',
                     'PorcentajeVacunacion':'0'})
    writer.writerow({'CodDepartamento': '19',
                     'CodCiudad':'001',
                     'Departamento': 'Cauca',
                     'Ciudad':'Popayan',
                     'Ano':'2020',
                     'Trimestre':'2',
                     'PorcentajeVacunacion':'0'})
    writer.writerow({'CodDepartamento': '17',
                     'CodCiudad':'001',
                     'Departamento': 'Caldas',
                     'Ciudad':'Manizales',
                     'Ano':'2020',
                     'Trimestre':'2',
                     'PorcentajeVacunacion':'0'})
    writer.writerow({'CodDepartamento': '76',
                     'CodCiudad':'001',
                     'Departamento': 'Valle del Cauca',
                     'Ciudad':'Cali',
                     'Ano':'2020',
                     'Trimestre':'2',
                     'PorcentajeVacunacion':'0'})
    writer.writerow({'CodDepartamento': '63',
                     'CodCiudad':'001',
                     'Departamento': 'Quindio',
                     'Ciudad':'Armenia',
                     'Ano':'2020',
                     'Trimestre':'2',
                     'PorcentajeVacunacion':'0'})
    writer.writerow({'CodDepartamento': '05',
                     'CodCiudad':'001',
                     'Departamento': 'Antioquia',
                     'Ciudad':'Medellin',
                     'Ano':'2020',
                     'Trimestre':'2',
                     'PorcentajeVacunacion':'0'})
    writer.writerow({'CodDepartamento': '23',
                     'CodCiudad':'001',
                     'Departamento': 'Cordoba',
                     'Ciudad':'Monteria',
                     'Ano':'2020',
                     'Trimestre':'2',
                     'PorcentajeVacunacion':'0'})
    writer.writerow({'CodDepartamento': '18',
                     'CodCiudad':'001',
                     'Departamento': 'Caqueta',
                     'Ciudad':'Florencia',
                     'Ano':'2020',
                     'Trimestre':'2',
                     'PorcentajeVacunacion':'0'})
    writer.writerow({'CodDepartamento': '47',
                     'CodCiudad':'001',
                     'Departamento': 'Magdalena',
                     'Ciudad':'Santa Marta',
                     'Ano':'2020',
                     'Trimestre':'2',
                     'PorcentajeVacunacion':'0'})
    writer.writerow({'CodDepartamento': '66',
                     'CodCiudad':'001',
                     'Departamento': 'Risaralda',
                     'Ciudad':'Pereira',
                     'Ano':'2020',
                     'Trimestre':'2',
                     'PorcentajeVacunacion':'0'})
    writer.writerow({'CodDepartamento': '70',
                     'CodCiudad':'001',
                     'Departamento': 'Sucre',
                     'Ciudad':'Sincelejo',
                     'Ano':'2020',
                     'Trimestre':'2',
                     'PorcentajeVacunacion':'0'})
    writer.writerow({'CodDepartamento': '52',
                     'CodCiudad':'001',
                     'Departamento': 'Narino',
                     'Ciudad':'Pasto',
                     'Ano':'2020',
                     'Trimestre':'2',
                     'PorcentajeVacunacion':'0'})
    writer.writerow({'CodDepartamento': '68',
                     'CodCiudad':'001',
                     'Departamento': 'Santander',
                     'Ciudad':'Bucaramanga',
                     'Ano':'2020',
                     'Trimestre':'2',
                     'PorcentajeVacunacion':'0'})
    writer.writerow({'CodDepartamento': '08',
                     'CodCiudad':'001',
                     'Departamento': 'Atlantico',
                     'Ciudad':'Barranquilla',
                     'Ano':'2020',
                     'Trimestre':'2',
                     'PorcentajeVacunacion':'0'})
    writer.writerow({'CodDepartamento': '13',
                     'CodCiudad':'001',
                     'Departamento': 'Bolivar',
                     'Ciudad':'Cartagena',
                     'Ano':'2020',
                     'Trimestre':'2',
                     'PorcentajeVacunacion':'0'})
    writer.writerow({'CodDepartamento': '88',
                     'CodCiudad':'001',
                     'Departamento': 'Archipielago de San Andres',
                     'Ciudad':'San Andres',
                     'Ano':'2020',
                     'Trimestre':'2',
                     'PorcentajeVacunacion':'0'})
    writer.writerow({'CodDepartamento': '44',
                     'CodCiudad':'001',
                     'Departamento':'Guajira',
                     'Ciudad':'Riohacha',
                     'Ano':'2020',
                     'Trimestre':'3',
                     'PorcentajeVacunacion':'0'})
    writer.writerow({'CodDepartamento': '54',
                     'CodCiudad':'001',
                     'Departamento': 'Norte de Santander',
                     'Ciudad':'Cucuta',
                     'Ano':'2020',
                     'Trimestre':'3',
                     'PorcentajeVacunacion':'0'})
    writer.writerow({'CodDepartamento': '27',
                     'CodCiudad':'001',
                     'Departamento': 'Choco',
                     'Ciudad':'Quibdo',
                     'Ano':'2020',
                     'Trimestre':'3',
                     'PorcentajeVacunacion':'0'})
    writer.writerow({'CodDepartamento': '73',
                     'CodCiudad':'001',
                     'Departamento': 'Tolima',
                     'Ciudad':'Ibague',
                     'Ano':'2020',
                     'Trimestre':'3',
                     'PorcentajeVacunacion':'0'})
    writer.writerow({'CodDepartamento': '41',
                     'CodCiudad':'001',
                     'Departamento': 'Huila',
                     'Ciudad':'Neiva',
                     'Ano':'2020',
                     'Trimestre':'3',
                     'PorcentajeVacunacion':'0'})
    writer.writerow({'CodDepartamento': '20',
                     'CodCiudad':'001',
                     'Departamento': 'Cesar',
                     'Ciudad':'Valledupar',
                     'Ano':'2020',
                     'Trimestre':'3',
                     'PorcentajeVacunacion':'0'})
    writer.writerow({'CodDepartamento': '11',
                     'CodCiudad':'001',
                     'Departamento': 'Bogota D.C',
                     'Ciudad':'Bogota D.C',
                     'Ano':'2020',
                     'Trimestre':'3',
                     'PorcentajeVacunacion':'0'})
    writer.writerow({'CodDepartamento': '15',
                     'CodCiudad':'001',
                     'Departamento': 'Boyaca',
                     'Ciudad':'Tunja',
                     'Ano':'2020',
                     'Trimestre':'3',
                     'PorcentajeVacunacion':'0'})
    writer.writerow({'CodDepartamento': '50',
                     'CodCiudad':'001',
                     'Departamento': 'Meta',
                     'Ciudad':'Villavicencio',
                     'Ano':'2020',
                     'Trimestre':'3',
                     'PorcentajeVacunacion':'0'})
    writer.writerow({'CodDepartamento': '19',
                     'CodCiudad':'001',
                     'Departamento': 'Cauca',
                     'Ciudad':'Popayan',
                     'Ano':'2020',
                     'Trimestre':'3',
                     'PorcentajeVacunacion':'0'})
    writer.writerow({'CodDepartamento': '17',
                     'CodCiudad':'001',
                     'Departamento': 'Caldas',
                     'Ciudad':'Manizales',
                     'Ano':'2020',
                     'Trimestre':'3',
                     'PorcentajeVacunacion':'0'})
    writer.writerow({'CodDepartamento': '76',
                     'CodCiudad':'001',
                     'Departamento': 'Valle del Cauca',
                     'Ciudad':'Cali',
                     'Ano':'2020',
                     'Trimestre':'3',
                     'PorcentajeVacunacion':'0'})
    writer.writerow({'CodDepartamento': '63',
                     'CodCiudad':'001',
                     'Departamento': 'Quindio',
                     'Ciudad':'Armenia',
                     'Ano':'2020',
                     'Trimestre':'3',
                     'PorcentajeVacunacion':'0'})
    writer.writerow({'CodDepartamento': '05',
                     'CodCiudad':'001',
                     'Departamento': 'Antioquia',
                     'Ciudad':'Medellin',
                     'Ano':'2020',
                     'Trimestre':'3',
                     'PorcentajeVacunacion':'0'})
    writer.writerow({'CodDepartamento': '23',
                     'CodCiudad':'001',
                     'Departamento': 'Cordoba',
                     'Ciudad':'Monteria',
                     'Ano':'2020',
                     'Trimestre':'3',
                     'PorcentajeVacunacion':'0'})
    writer.writerow({'CodDepartamento': '18',
                     'CodCiudad':'001',
                     'Departamento': 'Caqueta',
                     'Ciudad':'Florencia',
                     'Ano':'2020',
                     'Trimestre':'3',
                     'PorcentajeVacunacion':'0'})
    writer.writerow({'CodDepartamento': '47',
                     'CodCiudad':'001',
                     'Departamento': 'Magdalena',
                     'Ciudad':'Santa Marta',
                     'Ano':'2020',
                     'Trimestre':'3',
                     'PorcentajeVacunacion':'0'})
    writer.writerow({'CodDepartamento': '66',
                     'CodCiudad':'001',
                     'Departamento': 'Risaralda',
                     'Ciudad':'Pereira',
                     'Ano':'2020',
                     'Trimestre':'3',
                     'PorcentajeVacunacion':'0'})
    writer.writerow({'CodDepartamento': '70',
                     'CodCiudad':'001',
                     'Departamento': 'Sucre',
                     'Ciudad':'Sincelejo',
                     'Ano':'2020',
                     'Trimestre':'3',
                     'PorcentajeVacunacion':'0'})
    writer.writerow({'CodDepartamento': '52',
                     'CodCiudad':'001',
                     'Departamento': 'Narino',
                     'Ciudad':'Pasto',
                     'Ano':'2020',
                     'Trimestre':'3',
                     'PorcentajeVacunacion':'0'})
    writer.writerow({'CodDepartamento': '68',
                     'CodCiudad':'001',
                     'Departamento': 'Santander',
                     'Ciudad':'Bucaramanga',
                     'Ano':'2020',
                     'Trimestre':'3',
                     'PorcentajeVacunacion':'0'})
    writer.writerow({'CodDepartamento': '08',
                     'CodCiudad':'001',
                     'Departamento': 'Atlantico',
                     'Ciudad':'Barranquilla',
                     'Ano':'2020',
                     'Trimestre':'3',
                     'PorcentajeVacunacion':'0'})
    writer.writerow({'CodDepartamento': '13',
                     'CodCiudad':'001',
                     'Departamento': 'Bolivar',
                     'Ciudad':'Cartagena',
                     'Ano':'2020',
                     'Trimestre':'3',
                     'PorcentajeVacunacion':'0'})
    writer.writerow({'CodDepartamento': '88',
                     'CodCiudad':'001',
                     'Departamento': 'Archipielago de San Andres',
                     'Ciudad':'San Andres',
                     'Ano':'2020',
                     'Trimestre':'3',
                     'PorcentajeVacunacion':'0'})    
    writer.writerow({'CodDepartamento': '44',
                     'CodCiudad':'001',
                     'Departamento':'Guajira',
                     'Ciudad':'Riohacha',
                     'Ano':'2020',
                     'Trimestre':'4',
                     'PorcentajeVacunacion':'0'})
    writer.writerow({'CodDepartamento': '54',
                     'CodCiudad':'001',
                     'Departamento': 'Norte de Santander',
                     'Ciudad':'Cucuta',
                     'Ano':'2020',
                     'Trimestre':'4',
                     'PorcentajeVacunacion':'0'})
    writer.writerow({'CodDepartamento': '27',
                     'CodCiudad':'001',
                     'Departamento': 'Choco',
                     'Ciudad':'Quibdo',
                     'Ano':'2020',
                     'Trimestre':'4',
                     'PorcentajeVacunacion':'0'})
    writer.writerow({'CodDepartamento': '73',
                     'CodCiudad':'001',
                     'Departamento': 'Tolima',
                     'Ciudad':'Ibague',
                     'Ano':'2020',
                     'Trimestre':'4',
                     'PorcentajeVacunacion':'0'})
    writer.writerow({'CodDepartamento': '41',
                     'CodCiudad':'001',
                     'Departamento': 'Huila',
                     'Ciudad':'Neiva',
                     'Ano':'2020',
                     'Trimestre':'4',
                     'PorcentajeVacunacion':'0'})
    writer.writerow({'CodDepartamento': '20',
                     'CodCiudad':'001',
                     'Departamento': 'Cesar',
                     'Ciudad':'Valledupar',
                     'Ano':'2020',
                     'Trimestre':'4',
                     'PorcentajeVacunacion':'0'})
    writer.writerow({'CodDepartamento': '11',
                     'CodCiudad':'001',
                     'Departamento': 'Bogota D.C',
                     'Ciudad':'Bogota D.C',
                     'Ano':'2020',
                     'Trimestre':'4',
                     'PorcentajeVacunacion':'0'})
    writer.writerow({'CodDepartamento': '15',
                     'CodCiudad':'001',
                     'Departamento': 'Boyaca',
                     'Ciudad':'Tunja',
                     'Ano':'2020',
                     'Trimestre':'4',
                     'PorcentajeVacunacion':'0'})
    writer.writerow({'CodDepartamento': '50',
                     'CodCiudad':'001',
                     'Departamento': 'Meta',
                     'Ciudad':'Villavicencio',
                     'Ano':'2020',
                     'Trimestre':'4',
                     'PorcentajeVacunacion':'0'})
    writer.writerow({'CodDepartamento': '19',
                     'CodCiudad':'001',
                     'Departamento': 'Cauca',
                     'Ciudad':'Popayan',
                     'Ano':'2020',
                     'Trimestre':'4',
                     'PorcentajeVacunacion':'0'})
    writer.writerow({'CodDepartamento': '17',
                     'CodCiudad':'001',
                     'Departamento': 'Caldas',
                     'Ciudad':'Manizales',
                     'Ano':'2020',
                     'Trimestre':'4',
                     'PorcentajeVacunacion':'0'})
    writer.writerow({'CodDepartamento': '76',
                     'CodCiudad':'001',
                     'Departamento': 'Valle del Cauca',
                     'Ciudad':'Cali',
                     'Ano':'2020',
                     'Trimestre':'4',
                     'PorcentajeVacunacion':'0'})
    writer.writerow({'CodDepartamento': '63',
                     'CodCiudad':'001',
                     'Departamento': 'Quindio',
                     'Ciudad':'Armenia',
                     'Ano':'2020',
                     'Trimestre':'4',
                     'PorcentajeVacunacion':'0'})
    writer.writerow({'CodDepartamento': '05',
                     'CodCiudad':'001',
                     'Departamento': 'Antioquia',
                     'Ciudad':'Medellin',
                     'Ano':'2020',
                     'Trimestre':'4',
                     'PorcentajeVacunacion':'0'})
    writer.writerow({'CodDepartamento': '23',
                     'CodCiudad':'001',
                     'Departamento': 'Cordoba',
                     'Ciudad':'Monteria',
                     'Ano':'2020',
                     'Trimestre':'4',
                     'PorcentajeVacunacion':'0'})
    writer.writerow({'CodDepartamento': '18',
                     'CodCiudad':'001',
                     'Departamento': 'Caqueta',
                     'Ciudad':'Florencia',
                     'Ano':'2020',
                     'Trimestre':'4',
                     'PorcentajeVacunacion':'0'})
    writer.writerow({'CodDepartamento': '47',
                     'CodCiudad':'001',
                     'Departamento': 'Magdalena',
                     'Ciudad':'Santa Marta',
                     'Ano':'2020',
                     'Trimestre':'4',
                     'PorcentajeVacunacion':'0'})
    writer.writerow({'CodDepartamento': '66',
                     'CodCiudad':'001',
                     'Departamento': 'Risaralda',
                     'Ciudad':'Pereira',
                     'Ano':'2020',
                     'Trimestre':'4',
                     'PorcentajeVacunacion':'0'})
    writer.writerow({'CodDepartamento': '70',
                     'CodCiudad':'001',
                     'Departamento': 'Sucre',
                     'Ciudad':'Sincelejo',
                     'Ano':'2020',
                     'Trimestre':'4',
                     'PorcentajeVacunacion':'0'})
    writer.writerow({'CodDepartamento': '52',
                     'CodCiudad':'001',
                     'Departamento': 'Narino',
                     'Ciudad':'Pasto',
                     'Ano':'2020',
                     'Trimestre':'4',
                     'PorcentajeVacunacion':'0'})
    writer.writerow({'CodDepartamento': '68',
                     'CodCiudad':'001',
                     'Departamento': 'Santander',
                     'Ciudad':'Bucaramanga',
                     'Ano':'2020',
                     'Trimestre':'4',
                     'PorcentajeVacunacion':'0'})
    writer.writerow({'CodDepartamento': '08',
                     'CodCiudad':'001',
                     'Departamento': 'Atlantico',
                     'Ciudad':'Barranquilla',
                     'Ano':'2020',
                     'Trimestre':'4',
                     'PorcentajeVacunacion':'0'})
    writer.writerow({'CodDepartamento': '13',
                     'CodCiudad':'001',
                     'Departamento': 'Bolivar',
                     'Ciudad':'Cartagena',
                     'Ano':'2020',
                     'Trimestre':'4',
                     'PorcentajeVacunacion':'0'})
    writer.writerow({'CodDepartamento': '88',
                     'CodCiudad':'001',
                     'Departamento': 'Archipielago de San Andres',
                     'Ciudad':'San Andres',
                     'Ano':'2020',
                     'Trimestre':'4',
                     'PorcentajeVacunacion':'0'})
    
    
    
    
    #AÑO 2021
    
    
    writer.writerow({'CodDepartamento': '44',
                     'CodCiudad':'001',
                     'Departamento':'Guajira',
                     'Ciudad':'Riohacha',
                     'Ano':'2021',
                     'Trimestre':'1',
                     'PorcentajeVacunacion':'0.49'})
    writer.writerow({'CodDepartamento': '54',
                     'CodCiudad':'001',
                     'Departamento': 'Norte de Santander',
                     'Ciudad':'Cucuta',
                     'Ano':'2021',
                     'Trimestre':'1',
                     'PorcentajeVacunacion':'0.68'})
    writer.writerow({'CodDepartamento': '27',
                     'CodCiudad':'001',
                     'Departamento': 'Choco',
                     'Ciudad':'Quibdo',
                     'Ano':'2021',
                     'Trimestre':'1',
                     'PorcentajeVacunacion':'0.60'})
    writer.writerow({'CodDepartamento': '73',
                     'CodCiudad':'001',
                     'Departamento': 'Tolima',
                     'Ciudad':'Ibague',
                     'Ano':'2021',
                     'Trimestre':'1',
                     'PorcentajeVacunacion':'0.82'})
    writer.writerow({'CodDepartamento': '41',
                     'CodCiudad':'001',
                     'Departamento': 'Huila',
                     'Ciudad':'Neiva',
                     'Ano':'2021',
                     'Trimestre':'1',
                     'PorcentajeVacunacion':'0.92'})
    writer.writerow({'CodDepartamento': '20',
                     'CodCiudad':'001',
                     'Departamento': 'Cesar',
                     'Ciudad':'Valledupar',
                     'Ano':'2021',
                     'Trimestre':'1',
                     'PorcentajeVacunacion':'0.61'})
    writer.writerow({'CodDepartamento': '11',
                     'CodCiudad':'001',
                     'Departamento': 'Bogota D.C',
                     'Ciudad':'Bogota D.C',
                     'Ano':'2021',
                     'Trimestre':'1',
                     'PorcentajeVacunacion':'0.97'})
    writer.writerow({'CodDepartamento': '15',
                     'CodCiudad':'001',
                     'Departamento': 'Boyaca',
                     'Ciudad':'Tunja',
                     'Ano':'2021',
                     'Trimestre':'1',
                     'PorcentajeVacunacion':'1.49'})
    writer.writerow({'CodDepartamento': '50',
                     'CodCiudad':'001',
                     'Departamento': 'Meta',
                     'Ciudad':'Villavicencio',
                     'Ano':'2021',
                     'Trimestre':'1',
                     'PorcentajeVacunacion':'0.56'})
    writer.writerow({'CodDepartamento': '19',
                     'CodCiudad':'001',
                     'Departamento': 'Cauca',
                     'Ciudad':'Popayan',
                     'Ano':'2021',
                     'Trimestre':'1',
                     'PorcentajeVacunacion':'0.92'})
    writer.writerow({'CodDepartamento': '17',
                     'CodCiudad':'001',
                     'Departamento': 'Caldas',
                     'Ciudad':'Manizales',
                     'Ano':'2021',
                     'Trimestre':'1',
                     'PorcentajeVacunacion':'0.74'})
    writer.writerow({'CodDepartamento': '76',
                     'CodCiudad':'001',
                     'Departamento': 'Valle del Cauca',
                     'Ciudad':'Cali',
                     'Ano':'2021',
                     'Trimestre':'1',
                     'PorcentajeVacunacion':'0.93'})
    writer.writerow({'CodDepartamento': '63',
                     'CodCiudad':'001',
                     'Departamento': 'Quindio',
                     'Ciudad':'Armenia',
                     'Ano':'2021',
                     'Trimestre':'1',
                     'PorcentajeVacunacion':'0.77'})
    writer.writerow({'CodDepartamento': '05',
                     'CodCiudad':'001',
                     'Departamento': 'Antioquia',
                     'Ciudad':'Medellin',
                     'Ano':'2021',
                     'Trimestre':'1',
                     'PorcentajeVacunacion':'0.66'})
    writer.writerow({'CodDepartamento': '23',
                     'CodCiudad':'001',
                     'Departamento': 'Cordoba',
                     'Ciudad':'Monteria',
                     'Ano':'2021',
                     'Trimestre':'1',
                     'PorcentajeVacunacion':'0.76'})
    writer.writerow({'CodDepartamento': '18',
                     'CodCiudad':'001',
                     'Departamento': 'Caqueta',
                     'Ciudad':'Florencia',
                     'Ano':'2021',
                     'Trimestre':'1',
                     'PorcentajeVacunacion':'0.62'})
    writer.writerow({'CodDepartamento': '47',
                     'CodCiudad':'001',
                     'Departamento': 'Magdalena',
                     'Ciudad':'Santa Marta',
                     'Ano':'2021',
                     'Trimestre':'1',
                     'PorcentajeVacunacion':'0.58'})
    writer.writerow({'CodDepartamento': '66',
                     'CodCiudad':'001',
                     'Departamento': 'Risaralda',
                     'Ciudad':'Pereira',
                     'Ano':'2021',
                     'Trimestre':'1',
                     'PorcentajeVacunacion':'0.76'})
    writer.writerow({'CodDepartamento': '70',
                     'CodCiudad':'001',
                     'Departamento': 'Sucre',
                     'Ciudad':'Sincelejo',
                     'Ano':'2021',
                     'Trimestre':'1',
                     'PorcentajeVacunacion':'0.67'})
    writer.writerow({'CodDepartamento': '52',
                     'CodCiudad':'001',
                     'Departamento': 'Narino',
                     'Ciudad':'Pasto',
                     'Ano':'2021',
                     'Trimestre':'1',
                     'PorcentajeVacunacion':'1.31'})
    writer.writerow({'CodDepartamento': '68',
                     'CodCiudad':'001',
                     'Departamento': 'Santander',
                     'Ciudad':'Bucaramanga',
                     'Ano':'2021',
                     'Trimestre':'1',
                     'PorcentajeVacunacion':'0.88'})
    writer.writerow({'CodDepartamento': '08',
                     'CodCiudad':'001',
                     'Departamento': 'Atlantico',
                     'Ciudad':'Barranquilla',
                     'Ano':'2021',
                     'Trimestre':'1',
                     'PorcentajeVacunacion':'0.84'})
    writer.writerow({'CodDepartamento': '13',
                     'CodCiudad':'001',
                     'Departamento': 'Bolivar',
                     'Ciudad':'Cartagena',
                     'Ano':'2021',
                     'Trimestre':'1',
                     'PorcentajeVacunacion':'0.60'})
    writer.writerow({'CodDepartamento': '88',
                     'CodCiudad':'001',
                     'Departamento': 'Archipielago de San Andres',
                     'Ciudad':'San Andres',
                     'Ano':'2021',
                     'Trimestre':'1',
                     'PorcentajeVacunacion':'0.51'})
    writer.writerow({'CodDepartamento': '44',
                     'CodCiudad':'001',
                     'Departamento':'Guajira',
                     'Ciudad':'Riohacha',
                     'Ano':'2021',
                     'Trimestre':'2',
                     'PorcentajeVacunacion':'7.40'})
    writer.writerow({'CodDepartamento': '54',
                     'CodCiudad':'001',
                     'Departamento': 'Norte de Santander',
                     'Ciudad':'Cucuta',
                     'Ano':'2021',
                     'Trimestre':'2',
                     'PorcentajeVacunacion':'14.30'})
    writer.writerow({'CodDepartamento': '27',
                     'CodCiudad':'001',
                     'Departamento': 'Choco',
                     'Ciudad':'Quibdo',
                     'Ano':'2021',
                     'Trimestre':'2',
                     'PorcentajeVacunacion':'12.69'})
    writer.writerow({'CodDepartamento': '73',
                     'CodCiudad':'001',
                     'Departamento': 'Tolima',
                     'Ciudad':'Ibague',
                     'Ano':'2021',
                     'Trimestre':'2',
                     'PorcentajeVacunacion':'17.70'})
    writer.writerow({'CodDepartamento': '41',
                     'CodCiudad':'001',
                     'Departamento': 'Huila',
                     'Ciudad':'Neiva',
                     'Ano':'2021',
                     'Trimestre':'2',
                     'PorcentajeVacunacion':'15.53'})
    writer.writerow({'CodDepartamento': '20',
                     'CodCiudad':'001',
                     'Departamento': 'Cesar',
                     'Ciudad':'Valledupar',
                     'Ano':'2021',
                     'Trimestre':'2',
                     'PorcentajeVacunacion':'12.01'})
    writer.writerow({'CodDepartamento': '11',
                     'CodCiudad':'001',
                     'Departamento': 'Bogota D.C',
                     'Ciudad':'Bogota D.C',
                     'Ano':'2021',
                     'Trimestre':'2',
                     'PorcentajeVacunacion':'16.96'})
    writer.writerow({'CodDepartamento': '15',
                     'CodCiudad':'001',
                     'Departamento': 'Boyaca',
                     'Ciudad':'Tunja',
                     'Ano':'2021',
                     'Trimestre':'2',
                     'PorcentajeVacunacion':'20.97'})
    writer.writerow({'CodDepartamento': '50',
                     'CodCiudad':'001',
                     'Departamento': 'Meta',
                     'Ciudad':'Villavicencio',
                     'Ano':'2021',
                     'Trimestre':'2',
                     'PorcentajeVacunacion':'12.20'})
    writer.writerow({'CodDepartamento': '19',
                     'CodCiudad':'001',
                     'Departamento': 'Cauca',
                     'Ciudad':'Popayan',
                     'Ano':'2021',
                     'Trimestre':'2',
                     'PorcentajeVacunacion':'18.05'})
    writer.writerow({'CodDepartamento': '17',
                     'CodCiudad':'001',
                     'Departamento': 'Caldas',
                     'Ciudad':'Manizales',
                     'Ano':'2021',
                     'Trimestre':'2',
                     'PorcentajeVacunacion':'18.58'})
    writer.writerow({'CodDepartamento': '76',
                     'CodCiudad':'001',
                     'Departamento': 'Valle del Cauca',
                     'Ciudad':'Cali',
                     'Ano':'2021',
                     'Trimestre':'2',
                     'PorcentajeVacunacion':'15.72'})
    writer.writerow({'CodDepartamento': '63',
                     'CodCiudad':'001',
                     'Departamento': 'Quindio',
                     'Ciudad':'Armenia',
                     'Ano':'2021',
                     'Trimestre':'2',
                     'PorcentajeVacunacion':'20.21'})
    writer.writerow({'CodDepartamento': '05',
                     'CodCiudad':'001',
                     'Departamento': 'Antioquia',
                     'Ciudad':'Medellin',
                     'Ano':'2021',
                     'Trimestre':'2',
                     'PorcentajeVacunacion':'19.35'})
    writer.writerow({'CodDepartamento': '23',
                     'CodCiudad':'001',
                     'Departamento': 'Cordoba',
                     'Ciudad':'Monteria',
                     'Ano':'2021',
                     'Trimestre':'2',
                     'PorcentajeVacunacion':'12.24'})
    writer.writerow({'CodDepartamento': '18',
                     'CodCiudad':'001',
                     'Departamento': 'Caqueta',
                     'Ciudad':'Florencia',
                     'Ano':'2021',
                     'Trimestre':'2',
                     'PorcentajeVacunacion':'11.01'})
    writer.writerow({'CodDepartamento': '47',
                     'CodCiudad':'001',
                     'Departamento': 'Magdalena',
                     'Ciudad':'Santa Marta',
                     'Ano':'2021',
                     'Trimestre':'2',
                     'PorcentajeVacunacion':'11.49'})
    writer.writerow({'CodDepartamento': '66',
                     'CodCiudad':'001',
                     'Departamento': 'Risaralda',
                     'Ciudad':'Pereira',
                     'Ano':'2021',
                     'Trimestre':'2',
                     'PorcentajeVacunacion':'19.97'})
    writer.writerow({'CodDepartamento': '70',
                     'CodCiudad':'001',
                     'Departamento': 'Sucre',
                     'Ciudad':'Sincelejo',
                     'Ano':'2021',
                     'Trimestre':'2',
                     'PorcentajeVacunacion':'13.11'})
    writer.writerow({'CodDepartamento': '52',
                     'CodCiudad':'001',
                     'Departamento': 'Narino',
                     'Ciudad':'Pasto',
                     'Ano':'2021',
                     'Trimestre':'2',
                     'PorcentajeVacunacion':'20.15'})
    writer.writerow({'CodDepartamento': '68',
                     'CodCiudad':'001',
                     'Departamento': 'Santander',
                     'Ciudad':'Bucaramanga',
                     'Ano':'2021',
                     'Trimestre':'2',
                     'PorcentajeVacunacion':'19.99'})
    writer.writerow({'CodDepartamento': '08',
                     'CodCiudad':'001',
                     'Departamento': 'Atlantico',
                     'Ciudad':'Barranquilla',
                     'Ano':'2021',
                     'Trimestre':'2',
                     'PorcentajeVacunacion':'15.63'})
    writer.writerow({'CodDepartamento': '13',
                     'CodCiudad':'001',
                     'Departamento': 'Bolivar',
                     'Ciudad':'Cartagena',
                     'Ano':'2021',
                     'Trimestre':'2',
                     'PorcentajeVacunacion':'13.48'})
    writer.writerow({'CodDepartamento': '88',
                     'CodCiudad':'001',
                     'Departamento': 'Archipielago de San Andres',
                     'Ciudad':'San Andres',
                     'Ano':'2021',
                     'Trimestre':'2',
                     'PorcentajeVacunacion':'13.53'})
    writer.writerow({'CodDepartamento': '44',
                     'CodCiudad':'001',
                     'Departamento':'Guajira',
                     'Ciudad':'Riohacha',
                     'Ano':'2021',
                     'Trimestre':'3',
                     'PorcentajeVacunacion':'26.11'})
    writer.writerow({'CodDepartamento': '54',
                     'CodCiudad':'001',
                     'Departamento': 'Norte de Santander',
                     'Ciudad':'Cucuta',
                     'Ano':'2021',
                     'Trimestre':'3',
                     'PorcentajeVacunacion':'30.79'})
    writer.writerow({'CodDepartamento': '27',
                     'CodCiudad':'001',
                     'Departamento': 'Choco',
                     'Ciudad':'Quibdo',
                     'Ano':'2021',
                     'Trimestre':'3',
                     'PorcentajeVacunacion':'32.37'})
    writer.writerow({'CodDepartamento': '73',
                     'CodCiudad':'001',
                     'Departamento': 'Tolima',
                     'Ciudad':'Ibague',
                     'Ano':'2021',
                     'Trimestre':'3',
                     'PorcentajeVacunacion':'36.60'})
    writer.writerow({'CodDepartamento': '41',
                     'CodCiudad':'001',
                     'Departamento': 'Huila',
                     'Ciudad':'Neiva',
                     'Ano':'2021',
                     'Trimestre':'3',
                     'PorcentajeVacunacion':'32.85'})
    writer.writerow({'CodDepartamento': '20',
                     'CodCiudad':'001',
                     'Departamento': 'Cesar',
                     'Ciudad':'Valledupar',
                     'Ano':'2021',
                     'Trimestre':'3',
                     'PorcentajeVacunacion':'26.07'})
    writer.writerow({'CodDepartamento': '11',
                     'CodCiudad':'001',
                     'Departamento': 'Bogota D.C',
                     'Ciudad':'Bogota D.C',
                     'Ano':'2021',
                     'Trimestre':'3',
                     'PorcentajeVacunacion':'41.62'})
    writer.writerow({'CodDepartamento': '15',
                     'CodCiudad':'001',
                     'Departamento': 'Boyaca',
                     'Ciudad':'Tunja',
                     'Ano':'2021',
                     'Trimestre':'3',
                     'PorcentajeVacunacion':'43.36'})
    writer.writerow({'CodDepartamento': '50',
                     'CodCiudad':'001',
                     'Departamento': 'Meta',
                     'Ciudad':'Villavicencio',
                     'Ano':'2021',
                     'Trimestre':'3',
                     'PorcentajeVacunacion':'28.48'})
    writer.writerow({'CodDepartamento': '19',
                     'CodCiudad':'001',
                     'Departamento': 'Cauca',
                     'Ciudad':'Popayan',
                     'Ano':'2021',
                     'Trimestre':'3',
                     'PorcentajeVacunacion':'39.46'})
    writer.writerow({'CodDepartamento': '17',
                     'CodCiudad':'001',
                     'Departamento': 'Caldas',
                     'Ciudad':'Manizales',
                     'Ano':'2021',
                     'Trimestre':'3',
                     'PorcentajeVacunacion':'37.23'})
    writer.writerow({'CodDepartamento': '76',
                     'CodCiudad':'001',
                     'Departamento': 'Valle del Cauca',
                     'Ciudad':'Cali',
                     'Ano':'2021',
                     'Trimestre':'3',
                     'PorcentajeVacunacion':'33.06'})
    writer.writerow({'CodDepartamento': '63',
                     'CodCiudad':'001',
                     'Departamento': 'Quindio',
                     'Ciudad':'Armenia',
                     'Ano':'2021',
                     'Trimestre':'3',
                     'PorcentajeVacunacion':'40.41'})
    writer.writerow({'CodDepartamento': '05',
                     'CodCiudad':'001',
                     'Departamento': 'Antioquia',
                     'Ciudad':'Medellin',
                     'Ano':'2021',
                     'Trimestre':'3',
                     'PorcentajeVacunacion':'43.25'})
    writer.writerow({'CodDepartamento': '23',
                     'CodCiudad':'001',
                     'Departamento': 'Cordoba',
                     'Ciudad':'Monteria',
                     'Ano':'2021',
                     'Trimestre':'3',
                     'PorcentajeVacunacion':'28.46'})
    writer.writerow({'CodDepartamento': '18',
                     'CodCiudad':'001',
                     'Departamento': 'Caqueta',
                     'Ciudad':'Florencia',
                     'Ano':'2021',
                     'Trimestre':'3',
                     'PorcentajeVacunacion':'27.45'})
    writer.writerow({'CodDepartamento': '47',
                     'CodCiudad':'001',
                     'Departamento': 'Magdalena',
                     'Ciudad':'Santa Marta',
                     'Ano':'2021',
                     'Trimestre':'3',
                     'PorcentajeVacunacion':'25.63'})
    writer.writerow({'CodDepartamento': '66',
                     'CodCiudad':'001',
                     'Departamento': 'Risaralda',
                     'Ciudad':'Pereira',
                     'Ano':'2021',
                     'Trimestre':'3',
                     'PorcentajeVacunacion':'40.42'})
    writer.writerow({'CodDepartamento': '70',
                     'CodCiudad':'001',
                     'Departamento': 'Sucre',
                     'Ciudad':'Sincelejo',
                     'Ano':'2021',
                     'Trimestre':'3',
                     'PorcentajeVacunacion':'26.66'})
    writer.writerow({'CodDepartamento': '52',
                     'CodCiudad':'001',
                     'Departamento': 'Narino',
                     'Ciudad':'Pasto',
                     'Ano':'2021',
                     'Trimestre':'3',
                     'PorcentajeVacunacion':'38.92'})
    writer.writerow({'CodDepartamento': '68',
                     'CodCiudad':'001',
                     'Departamento': 'Santander',
                     'Ciudad':'Bucaramanga',
                     'Ano':'2021',
                     'Trimestre':'3',
                     'PorcentajeVacunacion':'39.0'})
    writer.writerow({'CodDepartamento': '08',
                     'CodCiudad':'001',
                     'Departamento': 'Atlantico',
                     'Ciudad':'Barranquilla',
                     'Ano':'2021',
                     'Trimestre':'3',
                     'PorcentajeVacunacion':'35.23'})
    writer.writerow({'CodDepartamento': '13',
                     'CodCiudad':'001',
                     'Departamento': 'Bolivar',
                     'Ciudad':'Cartagena',
                     'Ano':'2021',
                     'Trimestre':'3',
                     'PorcentajeVacunacion':'29.47'})
    writer.writerow({'CodDepartamento': '88',
                     'CodCiudad':'001',
                     'Departamento': 'Archipielago de San Andres',
                     'Ciudad':'San Andres',
                     'Ano':'2021',
                     'Trimestre':'3',
                     'PorcentajeVacunacion':'56.77'})
    writer.writerow({'CodDepartamento': '44',
                     'CodCiudad':'001',
                     'Departamento':'Guajira',
                     'Ciudad':'Riohacha',
                     'Ano':'2021',
                     'Trimestre':'4',
                     'PorcentajeVacunacion':'36.89'})
    writer.writerow({'CodDepartamento': '54',
                     'CodCiudad':'001',
                     'Departamento': 'Norte de Santander',
                     'Ciudad':'Cucuta',
                     'Ano':'2021',
                     'Trimestre':'4',
                     'PorcentajeVacunacion':'48.92'})
    writer.writerow({'CodDepartamento': '27',
                     'CodCiudad':'001',
                     'Departamento': 'Choco',
                     'Ciudad':'Quibdo',
                     'Ano':'2021',
                     'Trimestre':'4',
                     'PorcentajeVacunacion':'47.01'})
    writer.writerow({'CodDepartamento': '73',
                     'CodCiudad':'001',
                     'Departamento': 'Tolima',
                     'Ciudad':'Ibague',
                     'Ano':'2021',
                     'Trimestre':'4',
                     'PorcentajeVacunacion':'55.47'})
    writer.writerow({'CodDepartamento': '41',
                     'CodCiudad':'001',
                     'Departamento': 'Huila',
                     'Ciudad':'Neiva',
                     'Ano':'2021',
                     'Trimestre':'4',
                     'PorcentajeVacunacion':'53.70'})
    writer.writerow({'CodDepartamento': '20',
                     'CodCiudad':'001',
                     'Departamento': 'Cesar',
                     'Ciudad':'Valledupar',
                     'Ano':'2021',
                     'Trimestre':'4',
                     'PorcentajeVacunacion':'42.86'})
    writer.writerow({'CodDepartamento': '11',
                     'CodCiudad':'001',
                     'Departamento': 'Bogota D.C',
                     'Ciudad':'Bogota D.C',
                     'Ano':'2021',
                     'Trimestre':'4',
                     'PorcentajeVacunacion':'63.44'})
    writer.writerow({'CodDepartamento': '15',
                     'CodCiudad':'001',
                     'Departamento': 'Boyaca',
                     'Ciudad':'Tunja',
                     'Ano':'2021',
                     'Trimestre':'4',
                     'PorcentajeVacunacion':'66.04'})
    writer.writerow({'CodDepartamento': '50',
                     'CodCiudad':'001',
                     'Departamento': 'Meta',
                     'Ciudad':'Villavicencio',
                     'Ano':'2021',
                     'Trimestre':'4',
                     'PorcentajeVacunacion':'44.34'})
    writer.writerow({'CodDepartamento': '19',
                     'CodCiudad':'001',
                     'Departamento': 'Cauca',
                     'Ciudad':'Popayan',
                     'Ano':'2021',
                     'Trimestre':'4',
                     'PorcentajeVacunacion':'59.48'})
    writer.writerow({'CodDepartamento': '17',
                     'CodCiudad':'001',
                     'Departamento': 'Caldas',
                     'Ciudad':'Manizales',
                     'Ano':'2021',
                     'Trimestre':'4',
                     'PorcentajeVacunacion':'56.03'})
    writer.writerow({'CodDepartamento': '76',
                     'CodCiudad':'001',
                     'Departamento': 'Valle del Cauca',
                     'Ciudad':'Cali',
                     'Ano':'2021',
                     'Trimestre':'4',
                     'PorcentajeVacunacion':'48.04'})
    writer.writerow({'CodDepartamento': '63',
                     'CodCiudad':'001',
                     'Departamento': 'Quindio',
                     'Ciudad':'Armenia',
                     'Ano':'2021',
                     'Trimestre':'4',
                     'PorcentajeVacunacion':'57.45'})
    writer.writerow({'CodDepartamento': '05',
                     'CodCiudad':'001',
                     'Departamento': 'Antioquia',
                     'Ciudad':'Medellin',
                     'Ano':'2021',
                     'Trimestre':'4',
                     'PorcentajeVacunacion':'62.16'})
    writer.writerow({'CodDepartamento': '23',
                     'CodCiudad':'001',
                     'Departamento': 'Cordoba',
                     'Ciudad':'Monteria',
                     'Ano':'2021',
                     'Trimestre':'4',
                     'PorcentajeVacunacion':'43.55'})
    writer.writerow({'CodDepartamento': '18',
                     'CodCiudad':'001',
                     'Departamento': 'Caqueta',
                     'Ciudad':'Florencia',
                     'Ano':'2021',
                     'Trimestre':'4',
                     'PorcentajeVacunacion':'43.22'})
    writer.writerow({'CodDepartamento': '47',
                     'CodCiudad':'001',
                     'Departamento': 'Magdalena',
                     'Ciudad':'Santa Marta',
                     'Ano':'2021',
                     'Trimestre':'4',
                     'PorcentajeVacunacion':'41.42'})
    writer.writerow({'CodDepartamento': '66',
                     'CodCiudad':'001',
                     'Departamento': 'Risaralda',
                     'Ciudad':'Pereira',
                     'Ano':'2021',
                     'Trimestre':'4',
                     'PorcentajeVacunacion':'63.96'})
    writer.writerow({'CodDepartamento': '70',
                     'CodCiudad':'001',
                     'Departamento': 'Sucre',
                     'Ciudad':'Sincelejo',
                     'Ano':'2021',
                     'Trimestre':'4',
                     'PorcentajeVacunacion':'39.32'})
    writer.writerow({'CodDepartamento': '52',
                     'CodCiudad':'001',
                     'Departamento': 'Narino',
                     'Ciudad':'Pasto',
                     'Ano':'2021',
                     'Trimestre':'4',
                     'PorcentajeVacunacion':'60.12'})
    writer.writerow({'CodDepartamento': '68',
                     'CodCiudad':'001',
                     'Departamento': 'Santander',
                     'Ciudad':'Bucaramanga',
                     'Ano':'2021',
                     'Trimestre':'4',
                     'PorcentajeVacunacion':'60.93'})
    writer.writerow({'CodDepartamento': '08',
                     'CodCiudad':'001',
                     'Departamento': 'Atlantico',
                     'Ciudad':'Barranquilla',
                     'Ano':'2021',
                     'Trimestre':'4',
                     'PorcentajeVacunacion':'57.50'})
    writer.writerow({'CodDepartamento': '13',
                     'CodCiudad':'001',
                     'Departamento': 'Bolivar',
                     'Ciudad':'Cartagena',
                     'Ano':'2021',
                     'Trimestre':'4',
                     'PorcentajeVacunacion':'45.20'})
    writer.writerow({'CodDepartamento': '88',
                     'CodCiudad':'001',
                     'Departamento': 'Archipielago de San Andres',
                     'Ciudad':'San Andres',
                     'Ano':'2021',
                     'Trimestre':'4',
                     'PorcentajeVacunacion':'67.23'})
    
    
    
    
    #AÑO 2022
    
    
    
    writer.writerow({'CodDepartamento': '44',
                     'CodCiudad':'001',
                     'Departamento':'Guajira',
                     'Ciudad':'Riohacha',
                     'Ano':'2022',
                     'Trimestre':'1',
                     'PorcentajeVacunacion':'45.19'})
    writer.writerow({'CodDepartamento': '54',
                     'CodCiudad':'001',
                     'Departamento': 'Norte de Santander',
                     'Ciudad':'Cucuta',
                     'Ano':'2022',
                     'Trimestre':'1',
                     'PorcentajeVacunacion':'61.69'})
    writer.writerow({'CodDepartamento': '27',
                     'CodCiudad':'001',
                     'Departamento': 'Choco',
                     'Ciudad':'Quibdo',
                     'Ano':'2022',
                     'Trimestre':'1',
                     'PorcentajeVacunacion':'54.67'})
    writer.writerow({'CodDepartamento': '73',
                     'CodCiudad':'001',
                     'Departamento': 'Tolima',
                     'Ciudad':'Ibague',
                     'Ano':'2022',
                     'Trimestre':'1',
                     'PorcentajeVacunacion':'67.11'})
    writer.writerow({'CodDepartamento': '41',
                     'CodCiudad':'001',
                     'Departamento': 'Huila',
                     'Ciudad':'Neiva',
                     'Ano':'2022',
                     'Trimestre':'1',
                     'PorcentajeVacunacion':'65.65'})
    writer.writerow({'CodDepartamento': '20',
                     'CodCiudad':'001',
                     'Departamento': 'Cesar',
                     'Ciudad':'Valledupar',
                     'Ano':'2022',
                     'Trimestre':'1',
                     'PorcentajeVacunacion':'54.79'})
    writer.writerow({'CodDepartamento': '11',
                     'CodCiudad':'001',
                     'Departamento': 'Bogota D.C',
                     'Ciudad':'Bogota D.C',
                     'Ano':'2022',
                     'Trimestre':'1',
                     'PorcentajeVacunacion':'77.34'})
    writer.writerow({'CodDepartamento': '15',
                     'CodCiudad':'001',
                     'Departamento': 'Boyaca',
                     'Ciudad':'Tunja',
                     'Ano':'2022',
                     'Trimestre':'1',
                     'PorcentajeVacunacion':'77.73'})
    writer.writerow({'CodDepartamento': '50',
                     'CodCiudad':'001',
                     'Departamento': 'Meta',
                     'Ciudad':'Villavicencio',
                     'Ano':'2022',
                     'Trimestre':'1',
                     'PorcentajeVacunacion':'53.95'})
    writer.writerow({'CodDepartamento': '19',
                     'CodCiudad':'001',
                     'Departamento': 'Cauca',
                     'Ciudad':'Popayan',
                     'Ano':'2022',
                     'Trimestre':'1',
                     'PorcentajeVacunacion':'67.62'})
    writer.writerow({'CodDepartamento': '17',
                     'CodCiudad':'001',
                     'Departamento': 'Caldas',
                     'Ciudad':'Manizales',
                     'Ano':'2022',
                     'Trimestre':'1',
                     'PorcentajeVacunacion':'64.13'})
    writer.writerow({'CodDepartamento': '76',
                     'CodCiudad':'001',
                     'Departamento': 'Valle del Cauca',
                     'Ciudad':'Cali',
                     'Ano':'2022',
                     'Trimestre':'1',
                     'PorcentajeVacunacion':'55.97'})
    writer.writerow({'CodDepartamento': '63',
                     'CodCiudad':'001',
                     'Departamento': 'Quindio',
                     'Ciudad':'Armenia',
                     'Ano':'2022',
                     'Trimestre':'1',
                     'PorcentajeVacunacion':'65.92'})
    writer.writerow({'CodDepartamento': '05',
                     'CodCiudad':'001',
                     'Departamento': 'Antioquia',
                     'Ciudad':'Medellin',
                     'Ano':'2022',
                     'Trimestre':'1',
                     'PorcentajeVacunacion':'69.65'})
    writer.writerow({'CodDepartamento': '23',
                     'CodCiudad':'001',
                     'Departamento': 'Cordoba',
                     'Ciudad':'Monteria',
                     'Ano':'2022',
                     'Trimestre':'1',
                     'PorcentajeVacunacion':'55.01'})
    writer.writerow({'CodDepartamento': '18',
                     'CodCiudad':'001',
                     'Departamento': 'Caqueta',
                     'Ciudad':'Florencia',
                     'Ano':'2022',
                     'Trimestre':'1',
                     'PorcentajeVacunacion':'51.67'})
    writer.writerow({'CodDepartamento': '47',
                     'CodCiudad':'001',
                     'Departamento': 'Magdalena',
                     'Ciudad':'Santa Marta',
                     'Ano':'2022',
                     'Trimestre':'1',
                     'PorcentajeVacunacion':'50.57'})
    writer.writerow({'CodDepartamento': '66',
                     'CodCiudad':'001',
                     'Departamento': 'Risaralda',
                     'Ciudad':'Pereira',
                     'Ano':'2022',
                     'Trimestre':'1',
                     'PorcentajeVacunacion':'74.70'})
    writer.writerow({'CodDepartamento': '70',
                     'CodCiudad':'001',
                     'Departamento': 'Sucre',
                     'Ciudad':'Sincelejo',
                     'Ano':'2022',
                     'Trimestre':'1',
                     'PorcentajeVacunacion':'46.40'})
    writer.writerow({'CodDepartamento': '52',
                     'CodCiudad':'001',
                     'Departamento': 'Narino',
                     'Ciudad':'Pasto',
                     'Ano':'2022',
                     'Trimestre':'1',
                     'PorcentajeVacunacion':'71.58'})
    writer.writerow({'CodDepartamento': '68',
                     'CodCiudad':'001',
                     'Departamento': 'Santander',
                     'Ciudad':'Bucaramanga',
                     'Ano':'2022',
                     'Trimestre':'1',
                     'PorcentajeVacunacion':'72.50'})
    writer.writerow({'CodDepartamento': '08',
                     'CodCiudad':'001',
                     'Departamento': 'Atlantico',
                     'Ciudad':'Barranquilla',
                     'Ano':'2022',
                     'Trimestre':'1',
                     'PorcentajeVacunacion':'69.17'})
    writer.writerow({'CodDepartamento': '13',
                     'CodCiudad':'001',
                     'Departamento': 'Bolivar',
                     'Ciudad':'Cartagena',
                     'Ano':'2022',
                     'Trimestre':'1',
                     'PorcentajeVacunacion':'56.66'})
    writer.writerow({'CodDepartamento': '88',
                     'CodCiudad':'001',
                     'Departamento': 'Archipielago de San Andres',
                     'Ciudad':'San Andres',
                     'Ano':'2022',
                     'Trimestre':'1',
                     'PorcentajeVacunacion':'74.66'})
    writer.writerow({'CodDepartamento': '44',
                     'CodCiudad':'001',
                     'Departamento':'Guajira',
                     'Ciudad':'Riohacha',
                     'Ano':'2022',
                     'Trimestre':'2',
                     'PorcentajeVacunacion':'48.38'})
    writer.writerow({'CodDepartamento': '54',
                     'CodCiudad':'001',
                     'Departamento': 'Norte de Santander',
                     'Ciudad':'Cucuta',
                     'Ano':'2022',
                     'Trimestre':'2',
                     'PorcentajeVacunacion':'64.43'})
    writer.writerow({'CodDepartamento': '27',
                     'CodCiudad':'001',
                     'Departamento': 'Choco',
                     'Ciudad':'Quibdo',
                     'Ano':'2022',
                     'Trimestre':'2',
                     'PorcentajeVacunacion':'55.91'})
    writer.writerow({'CodDepartamento': '73',
                     'CodCiudad':'001',
                     'Departamento': 'Tolima',
                     'Ciudad':'Ibague',
                     'Ano':'2022',
                     'Trimestre':'2',
                     'PorcentajeVacunacion':'69.40'})
    writer.writerow({'CodDepartamento': '41',
                     'CodCiudad':'001',
                     'Departamento': 'Huila',
                     'Ciudad':'Neiva',
                     'Ano':'2022',
                     'Trimestre':'2',
                     'PorcentajeVacunacion':'69.03'})
    writer.writerow({'CodDepartamento': '20',
                     'CodCiudad':'001',
                     'Departamento': 'Cesar',
                     'Ciudad':'Valledupar',
                     'Ano':'2022',
                     'Trimestre':'2',
                     'PorcentajeVacunacion':'56.96'})
    writer.writerow({'CodDepartamento': '11',
                     'CodCiudad':'001',
                     'Departamento': 'Bogota D.C',
                     'Ciudad':'Bogota D.C',
                     'Ano':'2022',
                     'Trimestre':'2',
                     'PorcentajeVacunacion':'79.32'})
    writer.writerow({'CodDepartamento': '15',
                     'CodCiudad':'001',
                     'Departamento': 'Boyaca',
                     'Ciudad':'Tunja',
                     'Ano':'2022',
                     'Trimestre':'2',
                     'PorcentajeVacunacion':'79.44'})
    writer.writerow({'CodDepartamento': '50',
                     'CodCiudad':'001',
                     'Departamento': 'Meta',
                     'Ciudad':'Villavicencio',
                     'Ano':'2022',
                     'Trimestre':'2',
                     'PorcentajeVacunacion':'56.53'})
    writer.writerow({'CodDepartamento': '19',
                     'CodCiudad':'001',
                     'Departamento': 'Cauca',
                     'Ciudad':'Popayan',
                     'Ano':'2022',
                     'Trimestre':'2',
                     'PorcentajeVacunacion':'69.72'})
    writer.writerow({'CodDepartamento': '17',
                     'CodCiudad':'001',
                     'Departamento': 'Caldas',
                     'Ciudad':'Manizales',
                     'Ano':'2022',
                     'Trimestre':'2',
                     'PorcentajeVacunacion':'66.20'})
    writer.writerow({'CodDepartamento': '76',
                     'CodCiudad':'001',
                     'Departamento': 'Valle del Cauca',
                     'Ciudad':'Cali',
                     'Ano':'2022',
                     'Trimestre':'2',
                     'PorcentajeVacunacion':'58.19'})
    writer.writerow({'CodDepartamento': '63',
                     'CodCiudad':'001',
                     'Departamento': 'Quindio',
                     'Ciudad':'Armenia',
                     'Ano':'2022',
                     'Trimestre':'2',
                     'PorcentajeVacunacion':'69.19'})
    writer.writerow({'CodDepartamento': '05',
                     'CodCiudad':'001',
                     'Departamento': 'Antioquia',
                     'Ciudad':'Medellin',
                     'Ano':'2022',
                     'Trimestre':'2',
                     'PorcentajeVacunacion':'71.99'})
    writer.writerow({'CodDepartamento': '23',
                     'CodCiudad':'001',
                     'Departamento': 'Cordoba',
                     'Ciudad':'Monteria',
                     'Ano':'2022',
                     'Trimestre':'2',
                     'PorcentajeVacunacion':'57.22'})
    writer.writerow({'CodDepartamento': '18',
                     'CodCiudad':'001',
                     'Departamento': 'Caqueta',
                     'Ciudad':'Florencia',
                     'Ano':'2022',
                     'Trimestre':'2',
                     'PorcentajeVacunacion':'54.36'})
    writer.writerow({'CodDepartamento': '47',
                     'CodCiudad':'001',
                     'Departamento': 'Magdalena',
                     'Ciudad':'Santa Marta',
                     'Ano':'2022',
                     'Trimestre':'2',
                     'PorcentajeVacunacion':'52.27'})
    writer.writerow({'CodDepartamento': '66',
                     'CodCiudad':'001',
                     'Departamento': 'Risaralda',
                     'Ciudad':'Pereira',
                     'Ano':'2022',
                     'Trimestre':'2',
                     'PorcentajeVacunacion':'76.75'})
    writer.writerow({'CodDepartamento': '70',
                     'CodCiudad':'001',
                     'Departamento': 'Sucre',
                     'Ciudad':'Sincelejo',
                     'Ano':'2022',
                     'Trimestre':'2',
                     'PorcentajeVacunacion':'48.88'})
    writer.writerow({'CodDepartamento': '52',
                     'CodCiudad':'001',
                     'Departamento': 'Narino',
                     'Ciudad':'Pasto',
                     'Ano':'2022',
                     'Trimestre':'2',
                     'PorcentajeVacunacion':'73.71'})
    writer.writerow({'CodDepartamento': '68',
                     'CodCiudad':'001',
                     'Departamento': 'Santander',
                     'Ciudad':'Bucaramanga',
                     'Ano':'2022',
                     'Trimestre':'2',
                     'PorcentajeVacunacion':'74.91'})
    writer.writerow({'CodDepartamento': '08',
                     'CodCiudad':'001',
                     'Departamento': 'Atlantico',
                     'Ciudad':'Barranquilla',
                     'Ano':'2022',
                     'Trimestre':'2',
                     'PorcentajeVacunacion':'71.30'})
    writer.writerow({'CodDepartamento': '13',
                     'CodCiudad':'001',
                     'Departamento': 'Bolivar',
                     'Ciudad':'Cartagena',
                     'Ano':'2022',
                     'Trimestre':'2',
                     'PorcentajeVacunacion':'59.60'})
    writer.writerow({'CodDepartamento': '88',
                     'CodCiudad':'001',
                     'Departamento': 'Archipielago de San Andres',
                     'Ciudad':'San Andres',
                     'Ano':'2022',
                     'Trimestre':'2',
                     'PorcentajeVacunacion':'77.05'})
    writer.writerow({'CodDepartamento': '44',
                     'CodCiudad':'001',
                     'Departamento':'Guajira',
                     'Ciudad':'Riohacha',
                     'Ano':'2022',
                     'Trimestre':'3',
                     'PorcentajeVacunacion':'49.15'})
    writer.writerow({'CodDepartamento': '54',
                     'CodCiudad':'001',
                     'Departamento': 'Norte de Santander',
                     'Ciudad':'Cucuta',
                     'Ano':'2022',
                     'Trimestre':'3',
                     'PorcentajeVacunacion':'65.20'})
    writer.writerow({'CodDepartamento': '27',
                     'CodCiudad':'001',
                     'Departamento': 'Choco',
                     'Ciudad':'Quibdo',
                     'Ano':'2022',
                     'Trimestre':'3',
                     'PorcentajeVacunacion':'56.51'})
    writer.writerow({'CodDepartamento': '73',
                     'CodCiudad':'001',
                     'Departamento': 'Tolima',
                     'Ciudad':'Ibague',
                     'Ano':'2022',
                     'Trimestre':'3',
                     'PorcentajeVacunacion':'70.07'})
    writer.writerow({'CodDepartamento': '41',
                     'CodCiudad':'001',
                     'Departamento': 'Huila',
                     'Ciudad':'Neiva',
                     'Ano':'2022',
                     'Trimestre':'3',
                     'PorcentajeVacunacion':'69.98'})
    writer.writerow({'CodDepartamento': '20',
                     'CodCiudad':'001',
                     'Departamento': 'Cesar',
                     'Ciudad':'Valledupar',
                     'Ano':'2022',
                     'Trimestre':'3',
                     'PorcentajeVacunacion':'57.73'})
    writer.writerow({'CodDepartamento': '11',
                     'CodCiudad':'001',
                     'Departamento': 'Bogota D.C',
                     'Ciudad':'Bogota D.C',
                     'Ano':'2022',
                     'Trimestre':'3',
                     'PorcentajeVacunacion':'79.85'})
    writer.writerow({'CodDepartamento': '15',
                     'CodCiudad':'001',
                     'Departamento': 'Boyaca',
                     'Ciudad':'Tunja',
                     'Ano':'2022',
                     'Trimestre':'3',
                     'PorcentajeVacunacion':'79.99'})
    writer.writerow({'CodDepartamento': '50',
                     'CodCiudad':'001',
                     'Departamento': 'Meta',
                     'Ciudad':'Villavicencio',
                     'Ano':'2022',
                     'Trimestre':'3',
                     'PorcentajeVacunacion':'57.42'})
    writer.writerow({'CodDepartamento': '19',
                     'CodCiudad':'001',
                     'Departamento': 'Cauca',
                     'Ciudad':'Popayan',
                     'Ano':'2022',
                     'Trimestre':'3',
                     'PorcentajeVacunacion':'70.58'})
    writer.writerow({'CodDepartamento': '17',
                     'CodCiudad':'001',
                     'Departamento': 'Caldas',
                     'Ciudad':'Manizales',
                     'Ano':'2022',
                     'Trimestre':'3',
                     'PorcentajeVacunacion':'66.73'})
    writer.writerow({'CodDepartamento': '76',
                     'CodCiudad':'001',
                     'Departamento': 'Valle del Cauca',
                     'Ciudad':'Cali',
                     'Ano':'2022',
                     'Trimestre':'3',
                     'PorcentajeVacunacion':'58.96'})
    writer.writerow({'CodDepartamento': '63',
                     'CodCiudad':'001',
                     'Departamento': 'Quindio',
                     'Ciudad':'Armenia',
                     'Ano':'2022',
                     'Trimestre':'3',
                     'PorcentajeVacunacion':'70.16'})
    writer.writerow({'CodDepartamento': '05',
                     'CodCiudad':'001',
                     'Departamento': 'Antioquia',
                     'Ciudad':'Medellin',
                     'Ano':'2022',
                     'Trimestre':'3',
                     'PorcentajeVacunacion':'72.37'})
    writer.writerow({'CodDepartamento': '23',
                     'CodCiudad':'001',
                     'Departamento': 'Cordoba',
                     'Ciudad':'Monteria',
                     'Ano':'2022',
                     'Trimestre':'3',
                     'PorcentajeVacunacion':'58.05'})
    writer.writerow({'CodDepartamento': '18',
                     'CodCiudad':'001',
                     'Departamento': 'Caqueta',
                     'Ciudad':'Florencia',
                     'Ano':'2022',
                     'Trimestre':'3',
                     'PorcentajeVacunacion':'55.99'})
    writer.writerow({'CodDepartamento': '47',
                     'CodCiudad':'001',
                     'Departamento': 'Magdalena',
                     'Ciudad':'Santa Marta',
                     'Ano':'2022',
                     'Trimestre':'3',
                     'PorcentajeVacunacion':'53.01'})
    writer.writerow({'CodDepartamento': '66',
                     'CodCiudad':'001',
                     'Departamento': 'Risaralda',
                     'Ciudad':'Pereira',
                     'Ano':'2022',
                     'Trimestre':'3',
                     'PorcentajeVacunacion':'77.47'})
    writer.writerow({'CodDepartamento': '70',
                     'CodCiudad':'001',
                     'Departamento': 'Sucre',
                     'Ciudad':'Sincelejo',
                     'Ano':'2022',
                     'Trimestre':'3',
                     'PorcentajeVacunacion':'49.72'})
    writer.writerow({'CodDepartamento': '52',
                     'CodCiudad':'001',
                     'Departamento': 'Narino',
                     'Ciudad':'Pasto',
                     'Ano':'2022',
                     'Trimestre':'3',
                     'PorcentajeVacunacion':'74.37'})
    writer.writerow({'CodDepartamento': '68',
                     'CodCiudad':'001',
                     'Departamento': 'Santander',
                     'Ciudad':'Bucaramanga',
                     'Ano':'2022',
                     'Trimestre':'3',
                     'PorcentajeVacunacion':'75.73'})
    writer.writerow({'CodDepartamento': '08',
                     'CodCiudad':'001',
                     'Departamento': 'Atlantico',
                     'Ciudad':'Barranquilla',
                     'Ano':'2022',
                     'Trimestre':'3',
                     'PorcentajeVacunacion':'72.08'})
    writer.writerow({'CodDepartamento': '13',
                     'CodCiudad':'001',
                     'Departamento': 'Bolivar',
                     'Ciudad':'Cartagena',
                     'Ano':'2022',
                     'Trimestre':'3',
                     'PorcentajeVacunacion':'61.01'})
    writer.writerow({'CodDepartamento': '88',
                     'CodCiudad':'001',
                     'Departamento': 'Archipielago de San Andres',
                     'Ciudad':'San Andres',
                     'Ano':'2022',
                     'Trimestre':'3',
                     'PorcentajeVacunacion':'78.06'})
    
    
    
print("Datos insertados")
# Out:
# Datos insertados
